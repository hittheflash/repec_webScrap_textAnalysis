# %%
from pyresparser import ResumeParser

# %%
import os
pdfs = [i for i in os.listdir() if i.endswith("pdf")]
pdfs
# Out:
# ['paa9.pdf',
#  'pab1.pdf',
#  'pab10.pdf',
#  'pab175.pdf',
#  'pab7.pdf',
#  'pad89.pdf',
#  'pag15.pdf',
#  'pag175.pdf',
#  'pai18.pdf',
#  'pai23.pdf',
#  'pak55.pdf',
#  'pal14.pdf',
#  'pal207.pdf',
#  'pal266.pdf',
#  'pal356.pdf',
#  'pal67.pdf',
#  'pan2.pdf',
#  'pan29.pdf',
#  'pan30.pdf',
#  'pan31.pdf',
#  'pan42.pdf',
#  'pan51.pdf',
#  'pan56.pdf']

# %%
datas = ResumeParser('pad89.pdf').get_extracted_data()

# %%
datas
# Out:
# {'name': 'Curriculum Vitae',
#  'email': 'bbosworth@brookings.edu',
#  'mobile_number': '797-6122',
#  'skills': ['Presentation',
#   'Security',
#   'Higher education',
#   'International',
#   'Analysis',
#   'Administration',
#   'Money',
#   'Budget',
#   'Inventory',
#   'Finance',
#   'Statistics',
#   'Research',
#   'Public policy',
#   'Financing',
#   'Email',
#   'Tax',
#   'Health',
#   'Distribution',
#   'Banking',
#   'Economics',
#   'Green',
#   'Technical',
#   'Accounting',
#   'Reports'],
#  'college_name': None,
#  'degree': None,
#  'designation': None,
#  'experience': ['(with Kent Weaver). Center for Retirement Research, Boston College, November 2011.',
#   '“Innovations in U.S. Infrastructure Financing: An Evaluation,” (with Sveta Milusheva). Nomura',
#   'Foundation Conference on the Global Economy after the Tohoku Earthquake, November 2011.',
#   '7',
#   '8',
#   '“Recessions, Wealth Destruction, and the Timing of Retirement,” (with Gary Burtless). Center',
#   'for Retirement Research, Boston College, December 2010.',
#   '“Fiscal Consolidation in America: The Policy Options,” (with Rosanne Altshuler). Nomura',
#   'Foundation Conference on Fiscal Policy in the Post-Crisis World, November 2010.',
#   '“Integrating the Economic Accounts: Lessons from the Crisis,” NBER-CRIW Conference on',
#   'Wealth, Financial Intermediation and the Real Economy, November 2010.',
#   '“Price Deflators, the Trust Fund Forecast, and Social Security Solvency,” Center for Retirement',
#   'Research, Boston College, October 2010.',
#   '“The Role of Expenditure Reform in Fiscal Consolidations,” presentation at IMF Spring 2010',
#   'meetings.',
#   '“Rebalancing the U.S. Economy in a Post-Crisis World,” (with Susan Collins) presented at',
#   'ADB-Brookings Conference on Trans-Pacific Rebalancing (March, 2010).',
#   '“The U.S. External Deficit: A Soft Landing, Doomed or Delayed?” (with Susan Collins).',
#   'Conference of the Tokyo Club for Global Studies, November 2009.',
#   '“The Wealth of Older Americans and the Sub-prime Debacle,” (with Rosanna Smart).  Paper',
#   'prepared for the 2009 Annual Joint Conference of the Retirement Research Consortium (August)',
#   '“America’s Financial Crisis: the End of an Era,” (with Aaron Flaaen) Tokyo Club for Global',
#   'Studies, paper presented at the ADBI conference (April 2009).',
#   '“Financial Crises American Style,” (with Aaron Flaaen) paper presented at ASEAN Economic',
#   'Panel Forum (March 2009).',
#   '“Evaluating Micro-Survey Estimates of Wealth and Saving,” (with Rosanna Smart) January',
#   '2009.',
#   '“Saving and Wealth Accumulation in the PSID, 1984 – 2005,” (with Sarah Anders), January',
#   '2008.',
#   '“Is the 21st Century Productivity Expansion Still in Services? And What Should Be Done About',
#   'It?” (with Jack E. Triplett) presented at ASSA 2007 meetings (January 5-7)',
#   '“Accounting for Growth: Comparing China and India,” (with Susan M. Collins) Tokyo Club for',
#   'Global Studies (December 2006)',
#   '“Saving and Demographic Change: The Global Dimension,” (with Gabriel Chodorow-Reich),',
#   '8th Annual Joint Conference of the Retirement Research Consortium, August 2005',
#   '8',
#   'The Budget Crisis: Is It All Déjà Vu?  Tokyo Club for Global Studies (November 2005)',
#   '9',
#   '“The Decline in Household Saving: What Can We Learn From Survey Data?” (with Lisa Bell)',
#   '7th Annual Joint Conference of the Retirement Research Consortium, August 2005. Available at:',
#   'http://www.brookings.edu/papers/2005/0811saving_bosworth.aspx',
#   '"Challenges to the U.S. Economy: Economic Imbalances in a Growing Economy," Tokyo Club',
#   'for Global Studies (November 2004)',
#   '"Why Don\'t Americans Save?" 6th Annual Joint Conference of the Retirement Research',
#   'Consortium, (August 2004)',
#   '"The Impact of Aging on Financial Markets and the Economy: A Survey," with Ralph C. Bryant',
#   'and Gary Burtless (July 2004)',
#   '“Implications of the Bush Commission Pension Reforms for Married Couples,” (with Gary',
#   'Burtless and Benjamin Keys), Working paper, Center for Retirement Research at Boston',
#   'College, 2003.',
#   '“Economic and Distributional Effects of the Proposals of President Bush’s Social Security',
#   'Commission,” (with Gary Burtless), 4th Annual Joint Conference of the Retirement Research',
#   'Consortium, May 2002.',
#   '“The Trend in Lifetime Earnings Inequality and Its Impact on the Distribution of Retirement',
#   'Income,” (with Gary Burtless and Claudia Sahm), (2001) Working Paper, Center for Retirement',
#   'Research at Boston College.',
#   '9'],
#  'company_names': None,
#  'no_of_pages': 9,
#  'total_experience': 0.0}

# %%
datas = ResumeParser('pab1.pdf').get_extracted_data()
datas
# Out:
# {'name': 'http://www.jyrc.org Jeffrey',
#  'email': 'jcampbell@frbchi.org',
#  'mobile_number': '322-6156',
#  'skills': ['System',
#   'Research',
#   'Operations',
#   'Public policy',
#   'International',
#   'Presentations',
#   'Finance',
#   'Analysis',
#   'Economics',
#   'Retail',
#   'Email'],
#  'college_name': None,
#  'degree': None,
#  'designation': ['Assistant Professor'],
#  'experience': None,
#  'company_names': None,
#  'no_of_pages': 3,
#  'total_experience': 0}

# %%
# !pip install docx
# Out:
# Collecting docx
#   Downloading https://files.pythonhosted.org/packages/4a/8e/5a01644697b03016de339ef444cfff28367f92984dc74eddaab1ed60eada/docx-0.2.4.tar.gz (54kB)
# Requirement already satisfied: lxml in c:\users\jaimepanchana\anaconda3\lib\site-packages (from docx) (4.4.1)
# Requirement already satisfied: Pillow>=2.0 in c:\users\jaimepanchana\anaconda3\lib\site-packages (from docx) (6.2.0)
# Building wheels for collected packages: docx
#   Building wheel for docx (setup.py): started
#   Building wheel for docx (setup.py): finished with status 'done'
#   Created wheel for docx: filename=docx-0.2.4-cp37-none-any.whl size=53932 sha256=4c425e73ac196321040d5bdb3991e552c908e4497b3efc60ca736a55a960524d
#   Stored in directory: C:\Users\JaimePanchana\AppData\Local\pip\Cache\wheels\cc\8d\09\563edfd874a35c0c7ed129b6c4fa890efa4c26458bdec6ffc1
# Successfully built docx
# Installing collected packages: docx
# Successfully installed docx-0.2.4

# %%
# !pip install python-docx
# Out:
# Collecting python-docx
#   Downloading https://files.pythonhosted.org/packages/e4/83/c66a1934ed5ed8ab1dbb9931f1779079f8bca0f6bbc5793c06c4b5e7d671/python-docx-0.8.10.tar.gz (5.5MB)
# Requirement already satisfied: lxml>=2.3.2 in c:\users\jaimepanchana\anaconda3\lib\site-packages (from python-docx) (4.4.1)
# Building wheels for collected packages: python-docx
#   Building wheel for python-docx (setup.py): started
#   Building wheel for python-docx (setup.py): finished with status 'done'
#   Created wheel for python-docx: filename=python_docx-0.8.10-cp37-none-any.whl size=184496 sha256=a0d6294ce378a79e8a5a87a4558a8d3ebd9748291d89046f1984dfaf36b50410
#   Stored in directory: C:\Users\JaimePanchana\AppData\Local\pip\Cache\wheels\18\0b\a0\1dd62ff812c857c9e487f27d80d53d2b40531bec1acecfa47b
# Successfully built python-docx
# Installing collected packages: python-docx
# Successfully installed python-docx-0.8.10

# %%
import docx

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import XMLConverter, HTMLConverter, TextConverter
from pdfminer.layout import LAParams
import io

def pdfparser(data):

    fp = open(data, 'rb')
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    # Create a PDF interpreter object.
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    # Process each page contained in the document.

    for page in PDFPage.get_pages(fp):
        interpreter.process_page(page)
        data =  retstr.getvalue()

    print(data)

pdfparser('pab1.pdf')
# Out:
# Ofﬁce:
# Fax:
# Email:
# Web:
#
# (312) 322-6156
# (322) 322-2357
# jcampbell@frbchi.org
# http://www.jyrc.org
#
# Jeffrey R. Campbell
#
# Federal Reserve Bank of Chicago
# Economic Research Department
# 230 South LaSalle Street
# Chicago, IL 60604-1413
#
# Personal
# Date of Birth August 8, 1967
# United States
# Citizenship
#
# Academic Positions
# Senior Economist and Research Advisor
# External Fellow
# Senior Economist
# Faculty Research Fellow
# Assistant Professor
# Assistant Professor
#
# Publications
#
# Education
# Ph.D. in Economics Northwestern University
# A.B. in Economics
#
# June 1995
# University of Michigan (Residential College) April 1989
#
# Federal Reserve Bank of Chicago
# CentER, Tilburg University
# Federal Reserve Bank of Chicago
# NBER Economic Fluctuations and Growth March 1996–June 2009
# July 1999 – June 2002
# University of Chicago
# July 1994 – June 1999
# University of Rochester
#
# August 2011–present
# July 2012–present
# July 2002–July 2011
#
# Liquidity Constraints of the Middle Class
#
# with Zvi Hercowitz
# Forthcoming in American Economic Journal: Economic Policy
#
# Very Simple Markov-Perfect Industry Dynamics: Theory
#
# (with Jaap Abbring, Nan Yang, and Jan Tilly),
# Econometrica Volume 86, Number 2, pp. 721–735. March 2018.
#
# Forward Guidance and Macroeconomic Outcomes Since the Financial Crisis
#
# (with Jonas D.M. Fisher, Alejandro Justiniano, and Leonardo Melosi).
# 2016 NBER Macroeconomics Annual pp. 283–357.
#
# Rigid Prices: Evidence from U.S. Scanner Data (with Benjamin Eden).
#
# International Economic Review, Volume 55, Number 2, pp. 423–442. May 2014.
#
# Macroeconomic Effects of FOMC Forward Guidance
#
# (with Charles L. Evans, Jonas D.M. Fisher, and Alejandro Justiniano).
# Brookings Papers on Economic Activity, pp 1-54. Spring 2012.
#
# Competition in Large Markets.
#
# Journal of Applied Econometrics, Volume 26, Number 7. pp 1113-1136. November/December 2011.
#
# Last-In First-Out Oligopoly Dynamics (with Jaap H. Abbring).
#
# Econometrica, Volume 78, Number 5. pp 1491-1527. September 2010.
# (Please see the corrigendum for a corrected proof of equilibrium representation.)
#
# 1
#
# A Conversation with 590 Nascent Entrepreneurs (with Mariacristina De Nardi).
#
# Annals of Finance, Volume 5, Number 3, pp 313-340. June 2009.
#
# Welfare Effects of the Transition to High Household Debt (with Zvi Hercowitz).
#
# Journal of Monetary Economics, Volume 59, Number 1, pp. 1–16. January 2009.
#
# Market Size Matters (with Hugo Hopenhayn).
#
# Journal of Industrial Economics, Volume 53, Number 1, pp. 1–25. March 2005.
# (Please see the Erratum in Volume 55, Number 2, pp. 373–378, June 2007 for corrected tables).
#
# Real Exchange Rate Fluctuations and the Dynamics of Retail Trade Industries on the U.S.-Canada Border
# (with Beverly Lapham)
#
# American Economic Review, Volume 94, Number 4, pp. 1194–1206. September 2004.
#
# Idiosyncratic Risk and Aggregate Employment Dynamics (with Jonas D. M. Fisher)
#
# Review of Economic Dynamics, Volume 7, Number 2, pp. 331–353. April 2004.
#
# Aggregate Employment Fluctuations with Microeconomic Asymmetries (with Jonas D. M. Fisher)
#
# American Economic Review, Volume 90, Number 5, pp. 1323–1345. December 2000.
#
# Entry, Exit, Embodied Technology, and Business Cycles
#
# Review of Economic Dynamics, Volume 1, Number 2, pp. 371–408. April 1998.
#
# Macroeconomic Effects of Employment Reallocation (with Kenneth N. Kuttner)
#
# Carnegie-Rochester Conference Series on Public Policy, Volume 44, pp. 87–116. June 1996.
#
# Median Unbiasedness of Panel Data Censored Regression Models (with Bo E. Honoré)
#
# Econometric Theory, Volume 9, pp. 499–503. 1993.
#
# Working Papers
#
# Discretion Rather than Rules: Equilibrium Determinacy and Forward Guidance with Inconsistent Opti-
# mal Plans (with Jacob Weber), September 2018
#
# Open Mouth Operations (with Jacob Weber)
#
# Federal Reserve Bank of Chicago Working Paper 2018-03, February 2018.
#
# Very Simple Markov-Perfect Industry Dynamics: Empirics (with Jaap Abbring, Nan Yang, and Jan Tilly)
#
# CentER Discussion Paper 2018-040, July 2018.
#
# Quantitative Easing in Joseph’s Egypt with Keynesian Producers
#
# Federal Reserve Bank of Chicago Working Paper 2014-15, August 2016.
#
# The Economics of “Radiator Springs:” Industry Dynamics, Sunk Costs, and Spatial Demand Shifts
#
# (with Tom Hubbard)
# Federal Reserve Bank of Chicago Working Paper 2009-04, May 2016.
#
# Seminar and Conference Presentations, 2017-2018
#
# Discretion Rather than Rules: Equilibrium Determinacy and Forward Guidance with Inconsistent Opti-
# mal Plans
#
# Federal Reserve Bank of Cleveland Research Seminar
# IDC Herzliya Research Conference
# Northwestern University Macroeconomics Alumni Meeting
# European Economic Association Annual Meeting
#
# 2
#
# Quantitative Easing in Joseph’s Egypt with Keynesian Producers
#
# Midwest Macroeconomics Meeting
# Society for Economic Dynamics Annual Meeting
#
# Fellowships, Grants, and Awards
#
# Federal Reserve Bank of Chicago President’s Award for Excellence, 2012.
# AER Excellence in Refereeing Award, 2008.
# Journal of Industrial Economics Best Article of the Year for Market Size Matters (with Hugo A. Hopenhayn).
# National Science Foundation Grant SES-0137048, “Identiﬁcation and Estimation of Industry Dynamics
# Models with Persistent and Hidden State Variables”, April 2002 – March 2004.
# National Science Foundation Grant SES-9730442, “Business Cycles and Industry Dynamics,” March 1998
# – February 2000
# Alfred P. Sloan Doctoral Dissertation Fellowship, August 1992–July 1993.
#
# Recent Conference Organization
#
# I have selected papers and/or recruited discussants for
#
# Federal Reserve System Committee on Macroeconomic Analysis, October 2017 and April 2018.
# Northwestern University Macroeconomics Alumni Conferences, April 2014 and February 2016.
#
# Last updated: October 5, 2018
#
# http://www.jyrc.org/jyrc.pdf
#
# 3
