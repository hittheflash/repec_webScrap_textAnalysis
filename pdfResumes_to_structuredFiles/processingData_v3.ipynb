# %%
from pdfminer.pdfinterp import process_pdf
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from io import StringIO

from dateparser.search import search_dates
import pandas as pd
import os

from utills import clean_string
from utills import convert_pdf
from utills import lista_cargos
from utills import lista_inst

cargos = lista_cargos()
inst = lista_inst()

# %%
#print(lista_inst())

# %%
# engCV2.pdf
# galicv-5.pdf
# cv_brett.pdf
# cv2.pdf

# %%
def convert_pdf(path):

    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, laparams=laparams)

    fp = open(path, 'rb')
    process_pdf(rsrcmgr, device, fp)
    fp.close()
    device.close()

    strr = retstr.getvalue()
    retstr.close()
    return strr

rango = [str(i) for i in range(1950,2020)]
#print(rango)

# %%
file = open("john2.csv", "w")
file.write("nombre,categoria,cargo,instucion,year,descrip-cargo,descrip-intitucion,descrip-year\n")
# Out:
# 84

# %%
#Jordi Galí,Visiting Scholar,-Federal Reserve Bank of Boston,2005-06.,revisar/anadir intitucion,0

# %%
nombre = 'joan'

# %%
categories = {
    
    'education': {
        
        'education':['A.b.', 'a.b.', 'B.a.', 'b.a.', 'b.sc', 'B.sc', 'Bachelor', 'bachelor', 'M.Sc', 'M.a', 'M.a.', 'M.sc', 'm.a', 'm.a.', 'msc', 'm.sc', 'MSc', 'Msc', 'Ph. D.', 'Ph. d.', 'Ph.d', 'Ph.d.', 'ph. d.', 'ph.d', 'ph.d.', 'S.m.', 's.m.'],            
    },
    
    
    'honors and awards (Grants, Fellowships and Patents)': {
        'grant':  ["Advanced Grant", "Advanced grant", "Grant", "advanced grant", "grant"],
        'fellow': ["Faculty Research Fellow", "Faculty research fellow", "Fellow", "Fellowship", "International Research Fellow", "International research fellow", "Research Fellow", "Research Fellowship", "Research fellow", "Research fellowship", "Visiting Fellow", "Visiting fellow", "faculty research fellow", "fellow", "fellowship", "international research fellow", "research fellow", "research fellowship", "visiting fellow"],
        'council':["Council Member", "Council Member Diplom", "Council member", "Council member diplom", "council member", "council member diplom"],
        'member': ["Board Member", "Board member", "Elected Member", "Elected member", "Member", "Panel Member", "Panel member", "board member", "elected member", "member", "panel member"],
        'award':  ["Award", "award"],
        'prize':  ['prize', 'Prize']
    },            
    
    
    'experience': {
        'research': ['Research Assistant', 'Research Associate', 'Research Chair', 'Research Professor', 'Research Visitor', 'Research assistant', 'Research associate', 'Research chair', 'Research professor', 'Research visitor', 'research assistant', 'research associate', 'research chair', 'research professor', 'research visitor'],
    },        
    
    
    'employment': {
        'professor':            ["Associate Professor", "Visiting Assistant Professor", "Visiting Associate Professor", "Visiting Professor", "Visiting assistant professor", "Visiting associate professor", "Visiting professor", "associate professor", "visiting assistant professor", "visiting professor", "Adjunct Professor", "Adjunct Research Professor", "Adjunct professor", "Adjunct research professor", "Affiliated Professor", "Affiliated professor", "Assistant Professor", "Assistant Professor In Economics", "Assistant professor", "Assistant professor in economics", "Associate professor", "Booth Professor", "Booth professor", "Full Professor", "Full professor", "Professor", "Professor Of Economics", "Professor of economics", "University Professor", "University professor", "adjunct professor", "adjunct research professor", "affiliated professor", "assistant professor", "assistant professor in economics", "booth professor", "full professor", "professor", "professor of economics", "university professor"],
        'director/co-director': ["Directeur", "directeur", "Associate Director", "Associate director", "associate director", "Co-Director", "Co-director", "Director", "co-director", "director"],
        'lecturer':             ["Lecturer", "Senior Lecturer", "Senior lecturer", "lecturer", "senior lecturer"],
        'chair/chairman':       ["Chair", "Chairman", "chair", "chairman"],
        'visiting':             ["Visiting Postdoctoral Researcher", "Visiting Research Faculty", "Visiting Research Student", "Visiting Scholar", "Visiting Student", "Visiting postdoctoral researcher", "Visiting research faculty", "Visiting research student", "Visiting scholar", "Visiting student", "visiting postdoctoral researcher", "visiting research faculty", "visiting research student", "visiting scholar", "visiting student"],
        'associate':            ["Associate Editor", "Associate Faculty", "Associate Head", "Associate editor", "Associate faculty", "Associate head", "associate editor", "associate faculty", "associate head"],
        'teaching':             ["Teaching Assistant", "Teaching assistant", "teaching assistant"],
        'examiner':             ['External examiner', 'external examiner']
    },

    
    'editorial service': {
        'editor':["Assistant Editor", "Assistant editor", "Book Review Editor", "Book review editor", "Co-editor", "Editor-in-chief", "Editorial Board", "Editorial board", "Former Associate Editor", "Former associate editor", "Guest Editor", "Guest editor", "Invited Editor", "Invited editor", "assistant editor", "book review editor", "co-editor", "editor-in-chief", "editorial board", "former associate editor", "guest editor", "invited editor"],
    },
    
    
    'other experince': {
        'other':['Academic Visits', 'Academic visits', 'Computer Science Magnet', 'Computer science magnet', 'External Examiner', 'Gastprofessor', 'Instructor', 'Laurea', 'Mphil', 'Postdoctoral Researcher', 'Postdoctoral researcher', 'Project Advisor', 'Project advisor', 'Scholarship', 'Visitor', 'academic visits', 'computer science magnet', 'gastprofessor', 'instructor', 'laurea', 'mphil', 'postdoctoral researcher', 'project advisor', 'scholarship', 'visitor']
    }
}

# %%
categ = ""
for k in categories:
    validar = categories[k]
    for i in validar:
        print(i)
# Out:
# education
# grant
# fellow
# council
# member
# award
# prize
# research
# professor
# director/co-director
# lecturer
# chair/chairman
# visiting
# associate
# teaching
# examiner
# editor
# other

# %%
{'grant' : ["Advanced Grant", "Advanced grant", "Grant", "advanced grant", "grant"],
 'fellow': ["Faculty Research Fellow", "Faculty research fellow", "Fellow", "Fellowship", "International Research Fellow", "International research fellow", "Research Fellow", "Research Fellowship", "Research fellow", "Research fellowship", "Visiting Fellow", "Visiting fellow", "faculty research fellow", "fellow", "fellowship", "international research fellow", "research fellow", "research fellowship", "visiting fellow"],
 'council':["Council Member", "Council Member Diplom", "Council member", "Council member diplom", "council member", "council member diplom"],
 'member':["Board Member", "Board member", "Elected Member", "Elected member", "Member", "Panel Member", "Panel member", "board member", "elected member", "member", "panel member"],
 'award':["Award", "award"],
 'prize':['prize', 'Prize']
}
# Out:
# {'grant': ['Advanced Grant',
#   'Advanced grant',
#   'Grant',
#   'advanced grant',
#   'grant'],
#  'fellow': ['Faculty Research Fellow',
#   'Faculty research fellow',
#   'Fellow',
#   'Fellowship',
#   'International Research Fellow',
#   'International research fellow',
#   'Research Fellow',
#   'Research Fellowship',
#   'Research fellow',
#   'Research fellowship',
#   'Visiting Fellow',
#   'Visiting fellow',
#   'faculty research fellow',
#   'fellow',
#   'fellowship',
#   'international research fellow',
#   'research fellow',
#   'research fellowship',
#   'visiting fellow'],
#  'council': ['Council Member',
#   'Council Member Diplom',
#   'Council member',
#   'Council member diplom',
#   'council member',
#   'council member diplom'],
#  'member': ['Board Member',
#   'Board member',
#   'Elected Member',
#   'Elected member',
#   'Member',
#   'Panel Member',
#   'Panel member',
#   'board member',
#   'elected member',
#   'member',
#   'panel member'],
#  'award': ['Award', 'award'],
#  'prize': ['prize', 'Prize']}

# %%
{
    'professor':["Associate Professor", "Visiting Assistant Professor", "Visiting Associate Professor", "Visiting Professor", "Visiting assistant professor", "Visiting associate professor", "Visiting professor", "associate professor", "visiting assistant professor", "visiting professor", "Adjunct Professor", "Adjunct Research Professor", "Adjunct professor", "Adjunct research professor", "Affiliated Professor", "Affiliated professor", "Assistant Professor", "Assistant Professor In Economics", "Assistant professor", "Assistant professor in economics", "Associate professor", "Booth Professor", "Booth professor", "Full Professor", "Full professor", "Professor", "Professor Of Economics", "Professor of economics", "University Professor", "University professor", "adjunct professor", "adjunct research professor", "affiliated professor", "assistant professor", "assistant professor in economics", "booth professor", "full professor", "professor", "professor of economics", "university professor"],
    'director/co-director':["Directeur", "directeur", "Associate Director", "Associate director", "associate director", "Co-Director", "Co-director", "Director", "co-director", "director"],
    'lecturer':["Lecturer", "Senior Lecturer", "Senior lecturer", "lecturer", "senior lecturer"],
    'chair/chairman':["Chair", "Chairman", "chair", "chairman"],
    'visiting':["Visiting Postdoctoral Researcher", "Visiting Research Faculty", "Visiting Research Student", "Visiting Scholar", "Visiting Student", "Visiting postdoctoral researcher", "Visiting research faculty", "Visiting research student", "Visiting scholar", "Visiting student", "visiting postdoctoral researcher", "visiting research faculty", "visiting research student", "visiting scholar", "visiting student"],
    'associate':["Associate Editor", "Associate Faculty", "Associate Head", "Associate editor", "Associate faculty", "Associate head", "associate editor", "associate faculty", "associate head"],
    'assistant':["Teaching Assistant", "Teaching assistant", "teaching assistant"],
    'examiner':['External examiner', 'external examiner']
}

# %%
{
    'editor':["Assistant Editor", "Assistant editor", "Book Review Editor", "Book review editor", "Co-editor", "Editor-in-chief", "Editorial Board", "Editorial board", "Former Associate Editor", "Former associate editor", "Guest Editor", "Guest editor", "Invited Editor", "Invited editor", "assistant editor", "book review editor", "co-editor", "editor-in-chief", "editorial board", "former associate editor", "guest editor", "invited editor"],
    
}

# %%
['Academic Visits', 'Academic visits', 'Computer Science Magnet', 'Computer science magnet', 'External Examiner', 'Gastprofessor', 'Instructor', 'Laurea', 'Mphil', 'Postdoctoral Researcher', 'Postdoctoral researcher', 'Project Advisor', 'Project advisor', 'Scholarship', 'Visitor', 'academic visits', 'computer science magnet', 'gastprofessor', 'instructor', 'laurea', 'mphil', 'postdoctoral researcher', 'project advisor', 'scholarship', 'visitor']
}

# %%
f = ['Academic Visits', 'Academic visits', 'Computer Science Magnet', 'Computer science magnet', 'External Examiner', 'Gastprofessor', 'Instructor', 'Laurea', 'Mphil', 'Postdoctoral Researcher', 'Postdoctoral researcher', 'Project Advisor', 'Project advisor', 'Scholarship', 'Visitor', 'academic visits', 'computer science magnet', 'gastprofessor', 'instructor', 'laurea', 'mphil', 'postdoctoral researcher', 'project advisor', 'scholarship', 'visitor']

# %%
f
# Out:
# ['Academic Visits',
#  'Academic visits',
#  'Computer Science Magnet',
#  'Computer science magnet',
#  'External Examiner',
#  'Gastprofessor',
#  'Instructor',
#  'Laurea',
#  'Mphil',
#  'Postdoctoral Researcher',
#  'Postdoctoral researcher',
#  'Project Advisor',
#  'Project advisor',
#  'Scholarship',
#  'Visitor',
#  'academic visits',
#  'computer science magnet',
#  'gastprofessor',
#  'instructor',
#  'laurea',
#  'mphil',
#  'postdoctoral researcher',
#  'project advisor',
#  'scholarship',
#  'visitor']

# %%
for i in f:
    if "dito" in i:
        print('"{}",'.format(i), end=" ")
# Out:
# "Assistant Editor", "Assistant editor", "Book Review Editor", "Book review editor", "Co-editor", "Editor-in-chief", "Editorial Board", "Editorial board", "Former Associate Editor", "Former associate editor", "Guest Editor", "Guest editor", "Invited Editor", "Invited editor", "assistant editor", "book review editor", "co-editor", "editor-in-chief", "editorial board", "former associate editor", "guest editor", "invited editor",

# %%
for k in ["Assistant Editor", "Assistant editor", "Book Review Editor", "Book review editor", "Co-editor", "Editor-in-chief", "Editorial Board", "Editorial board", "Former Associate Editor", "Former associate editor", "Guest Editor", "Guest editor", "Invited Editor", "Invited editor", "assistant editor", "book review editor", "co-editor", "editor-in-chief", "editorial board", "former associate editor", "guest editor", "invited editor"]:
    f.remove(k)

# %%
for i in categories:
    print(categories[i])
    print()
# Out:
# ['A.b.', 'a.b.', 'B.a.', 'b.a.', 'b.sc', 'B.sc', 'Bachelor', 'bachelor', 'M.Sc', 'M.a', 'M.a.', 'M.sc', 'm.a', 'm.a.', 'msc', 'm.sc', 'MSc', 'Msc', 'Ph. D.', 'Ph. d.', 'Ph.d', 'Ph.d.', 'ph. d.', 'ph.d', 'ph.d.', 'S.m.', 's.m.']
#
# ['Advanced Grant', 'Advanced grant', 'Grant', 'advanced grant', 'grant', 'Faculty Research Fellow', 'Faculty research fellow', 'Fellow', 'Fellowship', 'International Research Fellow', 'International research fellow', 'prize', 'Research Fellow', 'Research Fellowship', 'Research fellow', 'Research fellowship', 'Visiting Fellow', 'Visiting fellow', 'faculty research fellow', 'fellow', 'fellowship', 'international research fellow', 'research fellow', 'research fellowship', 'visiting fellow', 'Award', 'award', 'Prize', 'Board Member', 'Board member', 'Council Member', 'Council Member Diplom', 'Council member', 'Council member diplom', 'Elected Member', 'Elected member', 'Member', 'Panel Member', 'Panel member', 'board member', 'council member', 'council member diplom', 'elected member', 'member', 'panel member']
#
# ['Research Assistant', 'Research Associate', 'Research Chair', 'Research Professor', 'Research Visitor', 'Research assistant', 'Research associate', 'Research chair', 'Research professor', 'Research visitor', 'research assistant', 'research associate', 'research chair', 'research professor', 'research visitor']
#
# ['External examiner', 'external examiner', 'Lecturer', 'Senior Lecturer', 'Senior lecturer', 'lecturer', 'senior lecturer', 'Directeur', 'directeur', 'Teaching Assistant', 'Teaching assistant', 'teaching assistant', 'Associate Director', 'Associate Editor', 'Associate Faculty', 'Associate Head', 'Associate Professor', 'Associate director', 'Associate editor', 'Associate faculty', 'Associate head', 'Visiting Assistant Professor', 'Visiting Associate Professor', 'Visiting Postdoctoral Researcher', 'Visiting Professor', 'Visiting Research Faculty', 'Visiting Research Student', 'Visiting Scholar', 'Visiting Student', 'Visiting assistant professor', 'Visiting associate professor', 'Visiting postdoctoral researcher', 'Visiting professor', 'Visiting research faculty', 'Visiting research student', 'Visiting scholar', 'Visiting student', 'associate director', 'associate editor', 'associate faculty', 'associate head', 'associate professor', 'visiting assistant professor', 'visiting postdoctoral researcher', 'visiting professor', 'visiting research faculty', 'visiting research student', 'visiting scholar', 'visiting student', 'Adjunct Professor', 'Adjunct Research Professor', 'Adjunct professor', 'Adjunct research professor', 'Affiliated Professor', 'Affiliated professor', 'Assistant Professor', 'Assistant Professor In Economics', 'Assistant professor', 'Assistant professor in economics', 'Associate professor', 'Booth Professor', 'Booth professor', 'Full Professor', 'Full professor', 'Professor', 'Professor Of Economics', 'Professor of economics', 'University Professor', 'University professor', 'adjunct professor', 'adjunct research professor', 'affiliated professor', 'assistant professor', 'assistant professor in economics', 'booth professor', 'full professor', 'professor', 'professor of economics', 'university professor', 'Chair', 'Chairman', 'chair', 'chairman', 'Co-Director', 'Co-director', 'Director', 'co-director', 'director']
#
# ['Assistant Editor', 'Assistant editor', 'Book Review Editor', 'Book review editor', 'Co-editor', 'Editor-in-chief', 'Editorial Board', 'Editorial board', 'Former Associate Editor', 'Former associate editor', 'Guest Editor', 'Guest editor', 'Invited Editor', 'Invited editor', 'assistant editor', 'book review editor', 'co-editor', 'editor-in-chief', 'editorial board', 'former associate editor', 'guest editor', 'invited editor']
#
# ['Academic Visits', 'Academic visits', 'Computer Science Magnet', 'Computer science magnet', 'External Examiner', 'Gastprofessor', 'Instructor', 'Laurea', 'Mphil', 'Postdoctoral Researcher', 'Postdoctoral researcher', 'Project Advisor', 'Project advisor', 'Scholarship', 'Visitor', 'academic visits', 'computer science magnet', 'gastprofessor', 'instructor', 'laurea', 'mphil', 'postdoctoral researcher', 'project advisor', 'scholarship', 'visitor']

# %%
cadena = convert_pdf("cv2.pdf")
cadena = cadena.replace(":  ", ": ")
cadena = cadena.replace(": ", ",")
cadena = cadena.replace("“", "")
cadena = cadena.replace("”", "")
lista = cadena.split("\n")
lista = [clean_string(i)[0] for i in lista if len(clean_string(i))>0]
lista
# Out:
# ['Joan Esteban CV, September 2014',
#  'CURRICULUM VITAE',
#  'Joan Esteban',
#  'GENERAL INFORMATION',
#  'Personal',
#  'Professional Address,',
#  'Name,',
#  'Juan María Esteban Marquillas',
#  'Place and date of birth,Barcelona, February 27th, 1945.',
#  'Private address,',
#  'Muntaner, 40-42 5º4ª 08011 Barcelona, Spain',
#  'Tel,34-934 513 729.',
#  'Institut d’Anàlisi Econòmica, CSIC',
#  'Campus UAB 08193 Bellaterra-Barcelona, Spain.',
#  'Tel,34-93-5806612, FAX:34-93-5801452',
#  'e-mail,joan.esteban@iae.csic.es',
#  'webpage,http://www.iae.csic.es',
#  'Academic Degrees',
#  'Oxford University, D. Phil., Economics, 1988.',
#  'Universitat Autònoma de Barcelona, Ph.D. Economics, 1973.',
#  'Universitat de Barcelona, B.A. Economics, 1967.',
#  'Current Position',
#  '1992-    ,Senior Researcher, Instituto de Análisis Económico, CSIC.',
#  '2011-    ,Senior Researcher, Barcelona GSE',
#  'Previous Positions',
#  '2000-05,',
#  'Professor Associat, Universitat Pompeu Fabra',
#  '1983-92,',
#  'Professor, Universitat Autònoma de Barcelona.',
#  '1977-83,',
#  'Associate Professor, Universitat Autònoma de Barcelona.',
#  '1975-77,',
#  'Assistant Professor, Universitat Autònoma de Barcelona.',
#  '1971-72,',
#  'Assistant Professor, Universitat Autònoma de Barcelona.',
#  '1970-72,',
#  'Economist. Comisión Mixta de Coordinación Estadística.',
#  '1970-71,',
#  'Teaching Assistant, Universitat Autònoma de Barcelona.',
#  '1967-70,',
#  'Teaching Assistant, Universidad de Barcelona.',
#  '1965-69,',
#  'Economist. Servicio de Estudios de Barcelona del Banco Urquijo.',
#  'Administrative Experience',
#  "2001-06,Director of the Institut d'Anàlisi Econòmica, CSIC.",
#  '1993-96,Presidential delegate',
#  'for Catalunya of',
#  'the Consejo Superior de',
#  'Investigaciones Científicas.',
#  '1990-96,Member of the Research Council of the European University Institute.',
#  '1989-96,Representantive of the Spanish government at the High Council of the',
#  'European University Institute.',
#  '1992-93,Member of the expert group in Economic, Social and Human Sciences of',
#  'the Human Capital and Mobility programme, Directorate-General for',
#  'Science, Research and Technology of the Commission for the EC.',
#  "1989-91,Director of the Institut d'Anàlisi Econòmica, CSIC.",
#  "1987-89,Vice-Director of the Institut d'Anàlisi Econòmica, CSIC.",
#  '1985-87,Department Chairman.',
#  '1980-82,Vice-Dean of the School of Economics and Business Administration.',
#  '1978-85,Director of the Graduate Program.',
#  '1',
#  'Joan Esteban CV, September 2014',
#  'PUBLICATIONS',
#  'ARTICLES IN JOURNALS',
#  '1. Strategic Mass Killings (with Massimo Morelli and Dominic Rohner),',
#  'forthcoming, Journal of Political Economy.',
#  '2.  Market Distortions and Government Transparency (with Facundo Albornoz',
#  'and Paolo Vanin), the Journal of the European Economic Association, 2014',
#  '12, 200-222.',
#  '3.  Ethnicity and Conflict,Theory and Facts (with Laura Mayoral and Debraj',
#  'Ray), Science 2012 336, 858-865.',
#  '4.  Ethnicity and Conflict,an Empirical Study (with Laura Mayoral and Debraj',
#  'Ray), American Economic Review 2012, 102 1310-1342.',
#  '5. Linking Conflict to Inequality and Polarization (with Debraj Ray), American',
#  'Economic Review 2011, 101 1345-1374.',
#  '6.  A Model of Ethnic Conflict (with Debraj Ray), The Journal of the European',
#  'Economic Association, 2011 9, 496–521.',
#  '7. Work Values, Endogenous Sentiments and Redistribution (with Matteo',
#  'Cervellati and Larry Kranich), Journal of Public Economics 2010 94, 212-227.',
#  '8. On the Salience of Ethnic Conflict (with Debraj Ray) American Economic',
#  'Review 2008, 98 2185–2202.',
#  '9. Polarization, Fractionalization and Conflict (with Debraj Ray), Journal of Peace',
#  'Research 2008 45,163-182.',
#  '10. A Theory of Agreements in the Shadow of Conflict,The Genesis of Bargaining',
#  'Power (with J. Sákovics), Theory and Decision 2008 65, 227-252.',
#  '11. Polarization and Conflict,Theoretical and Empirical Issues (with G.',
#  'Schneider), Journal of Peace Research 2008 45, 131-141.',
#  '12. "Stochastic Dominance and Absolute Risk Aversion" (with Jordi Caballé), Social',
#  'Choice and Welfare 2007 28 89-110.',
#  '13. An Extension of a Measure of Polarization, with an application to the income',
#  'distribution of five OECD countries (with Carlos Gradín and Debraj Ray),',
#  'Journal of Economic Inequality 2007 5, 1-19.',
#  '14. Inequality, Lobbying and Resource Allocation (with Debraj Ray), American',
#  'Economic Review March 2006, 96 257-279.',
#  '15. Social Groups and Economic Inequality (with C. Barret) Journal of Economic',
#  'Inequality, 2005 (3) 187-191.',
#  '16. Polarization,Concepts, Measurement, Estimation (with Jean-Yves Duclos and',
#  'Debraj Ray), Econometrica 2004, 72 1737-1772.',
#  '17. Olson vs. Coase,coalitional worth in conflict (with J. Sákovics), Theory and',
#  'Decision  2004, 55(4), 339-357.',
#  '18. Collective Action and the Group Size Paradox, (with D. Ray), American',
#  'Political Science Review 2001, 95 663-672.',
#  '19. Social Rules are not Immune to Conflict, (with D. Ray), Economics of',
#  'Governance, 2001, 2, 59-67, reprinted in A. Glazer and K.A. Konrad (eds)',
#  'Conflict and Governance, 193-201, Springer, 2003.',
#  '2',
#  'Joan Esteban CV, September 2014',
#  '20. Regional Convergence in Europe and the Industry-Mix,a Shift-Share Analysis,',
#  'Regional Science and Urban Economics 30 (2000), 353-364.',
#  '21. Wealth Constraints, Lobbying and the Efficiency of Public Allocation (with D.',
#  'Ray), European Economic Review 44 (2000), 694-705.',
#  '22. An Analysis of the Polarization of the Distribution of Provincial Income in Spain,',
#  '1955-1993 (in Spanish), Moneda y Crédito 2000, 11-50.',
#  '23. Conflict and Distribution (with D. Ray) Journal of Economic Theory 87 1999,',
#  '379-415.',
#  '24.  Catalonia within the Euro Area (in Catalan) (with J. Gual) Nota d’Economia 64',
#  '1999, 19-40.',
#  '25. Factor Decomposition of Cross-Country Income Inequality, 1960-1990 (with',
#  'J.A. Duro) Economics Letters, 60 1998, 269-275.',
#  '26. Costly Transfer Institutions and the Core in an Overlapping Generations Model',
#  '(with M. Engineer and J. Sákovics) Journal of Economic Behavior and',
#  'Organization,  32 1997, 285-300.',
#  '27. Inequality and Polarization,the inter-regional distribution of income in Spain',
#  '(in Spanish), Revista de Economía Aplicada, 4  1996, 5-26.',
#  '28. On the Measurement of Polarization, (with D. Ray), Econometrica,   62, 1994,',
#  'pp 819-852.',
#  '29. Efficient Monetary Equilibrium,An Overlapping Generations Model with',
#  'Nonstationary Monetary Policies (with T. Mitra and D. Ray), Journal of',
#  'Economic Theory, 64 1994, 372-389.',
#  '30. Intertemporal Transfer Institutions (with J. Sákovics), Journal of Economic',
#  'Theory, 61, 1993, 189-205.',
#  '31. Core Equivalence in an Overlapping Generations Model, (with S. Chae),',
#  'Journal of Economic Theory 59 1993, 417-425.',
#  '32. Social Welfare and Equality (with B. Dutta), Social Choice and Welfare, 9',
#  '1992, 267-276.',
#  '33. Interregional Income Inequalities in Spain and in Europe,equity, solidarity and',
#  'fiscal federalism (in Spanish), Economia y Sociedad 5, 1991 53-77.',
#  '34. Competitive Equilibria and the Core of Overlapping-Generations Economies',
#  '(with T. Millán), Journal of Economic Theory, 50, 1990, 155-174.',
#  '35. Notes on the Constitutional Principles and System of Fiscal Federalism in',
#  'Spain (in Spanish), , (with R. Gómez), De Economia Publica, 4/1990, 147-',
#  '175.',
#  '36. The Viability of the Extension to the Spanish Regions of the Basc Fiscal',
#  'Agreement (in Spanish) (with R. Gómez), Hacienda Publica Española, 116,',
#  '3/1990, 105-116.',
#  '37. Notes on the Constitutional Principles and System of Fiscal Federalism in',
#  'Spain (in Spanish), , (with R. Gómez), De Economia Publica, 4/1990, 147-',
#  '175.',
#  '38. The Viability of the Extension to the Spanish Regions of the Basc Fiscal',
#  'Agreement (in Spanish) (with R. Gómez), Hacienda Publica Española, 116,',
#  '3/1990, 105-116.',
#  '39. The Bounded Core of an Overlapping Generations Economy, (with S. Chae),',
#  'International Economic Review, 30, 1989, 519-526.',
#  '3',
#  'Joan Esteban CV, September 2014',
#  '40. Readings',
#  'in Overlapping-Generations Economies,an',
#  'Introduction (in',
#  'Spanish), Hacienda Publica Española, nº 100 , 1987,395-400.',
#  '41. Income-Share Elasticity and the Size Distribution of Income, International',
#  'Economic Review 27, 1986, pp. 439-444.',
#  '42. A Characterization of the Core in Overlapping-Generations Economies, Journal',
#  'of Economic Theory 39, 1986, pp. 439-456.',
#  '43. A Characterization of the Core in an Economy with Overlapping Generations',
#  '(in Spanish), Revista Española de Economía  2, nº 1, 1985, pp. 3-17.',
#  '44. Information, Incentives and the Theory of Taxation (in Spanish) (with X.',
#  'Calsamiglia), Hacienda Pública Española nº91, 1984, pp.245-259.',
#  '45. A Model for the Analysis of Unemployment, Efficiency and Distribution (in',
#  'Spanish) (with X. Calsamiglia), Investigaciones Económicas, nº 22, 1983, pp.',
#  '129-160.',
#  '46. Some Results on the Lorenz Curve and the Gini Coefficient (in Spanish),',
#  'Cuadernos de Economía, vol. 8, nº 22, 1980, pp. 191-224.',
#  '47. Dynamic Efficiency, Decentralization and Taxes (in Spanish), Hacienda Pública',
#  'Española, nº 61, 1979, pp. 91-100.',
#  '48. A Two-Sector Growth Model with Life-Cycle Savings (in Spanish),',
#  'Investigaciones Económicas, nº 5, 1978, pp. 89-103.',
#  '49. Optimal Fiscal Policy in an Economy wit a Public Sector (in Spanish),',
#  'Hacienda Pública Española, nº 51, 1978, pp.249-255.',
#  '50. Pasinetti’s Growth Model and Rational Behaviour (in Spanish), Cuadernos de',
#  'Economía, vol. 6, nº 15, 1978, pp. 57-67.',
#  '51. The Measurement of Income Inequality,A Skeptical View (in Spanish),',
#  'Moneda y Crédito, nº 140, 1977, pp.43-65.',
#  '52. A Model of Optimal Inheritance Taxation (in Spanish), Hacienda Pública',
#  'Española, nº 45, 1977, pp.119-142.',
#  '53. A Reinterpretation of Shift-Share Analysis, Regional and Urban Economics,',
#  'vol. 2, nº 3, 1972, 249-261.',
#  '54. A Technique for Regional Analysis (in Spanish), Moneda y Crédito, nº 104,',
#  '1968, pp.19-37.',
#  'BOOKS and EDITED SPECIAL JOURNAL ISSUES',
#  '1. Polarization and Conflict,Theoretical and Empirical Issues, J. Esteban and G.',
#  'Schneider (Editors), a special issue of the Journal of Peace Research 2008 45.',
#  '2. Social Groups and Economic Inequality, J. Esteban and C. Barret (Editors), a',
#  'special issue of the Journal of Economic Inequality, 2005 3.',
#  '3. Catalonia in the Euro Currency Area (in Spanish) (with J. Gual and contributions',
#  'from R. Boix, R. Caminal and P.Videla), Ed. Antoni Bosch, Barcelona, 1999.',
#  '4. Growth and Regional Convergence in Europe and Spain (in Spanish), 2 vols,',
#  '(with R. Caminal, A de la Fuente and X. Vives), Instituto de Análisis Económico,',
#  'CSIC, y Fundación de Economía Analítica, Barcelona, 1994.',
#  '5. The Social Viability of Fiat Money. The Core of Overlapping Generations',
#  'Economies, Lecture Notes in Economics and Mathematical Systems vol. 372,',
#  'Springer Verlag, 1991, 202 pp.',
#  '4',
#  'Joan Esteban CV, September 2014',
#  '6. The Financing of the Regional Governments (in Spanish)(co-authored),',
#  'Generalitat de Catalunya, Barcelona, 1991, 387 pp.',
#  '7. The Spanish Capitalism,from Autarky to the Stabilization Plan, 1939-59, (in',
#  'Spanish) (2 vols) (co-author), EDICUSA, Madrid, 1973. New revised edition,',
#  'EDICUSA, Madrid,1978.',
#  '8. Economic Development of Catalonia, 1967-1970 (in Spanish) (2 vols.) (co-',
#  'author), Sociedad de Estudios y Publicaciones, Barcelona, 1967.',
#  '5',
#  'Joan Esteban CV, September 2014',
#  'CHAPTERS IN BOOKS',
#  '1. Incentives and Constraints for Government Mass Killings (with Massimo',
#  'Morelli and Dominic Rohner), forthcoming in Economic Aspects of Genocide,',
#  'Mass Killings, and their Prevention, Oxford University Press.',
#  '2.  Comparing Polarization Measures (with Debraj Ray), in M. Garfinkel and S.',
#  'Skaperdas, Oxford Handbook of the Economics of Peace and Conflict, Oxford',
#  'University Press, 2012, 127-151.',
#  '3. Frontier Research in Economics in Frontiers of Knowledge, BBVA 2008, 315-',
#  '327.',
#  '4. Polarization,Concepts, Measurement, Estimation (with Jean-Yves Duclos and',
#  'Debraj Ray), in Christopher Barrett (ed.), The Social Economics of Poverty,On',
#  'Identities, Groups, Communities, and Networks, London,Routledge,  2005 56-',
#  '105 (reprint).',
#  '5. The Measurement of Polarization,where do we stand (in Spanish) in J. Ruiz-',
#  'Huerta (ed) Políticas Públicas y Distribución de la Renta, Fundación BBVA,',
#  'Madrid, 2005.',
#  '6. Social Rules are not Immune to Conflict, (with D. Ray), in A. Glazer and K.A.',
#  'Konrad (eds) Conflict and Governance, 193-201, Springer, 2003 (reprint).',
#  '7. "Overlapping Generation Models" in Fundamental Economics, edited by Mukul',
#  'Majumdar, in Encyclopedia of Life Support Systems (EOLSS), developed under',
#  'the auspices of the UNESCO, Eolss Publishers, Oxford, 2003.',
#  '8. An Analysis of Interregional Inequalities in Europe,the eighties, in A. Castells',
#  'i N. Bosch (eds.) Desequilibrios territoriales en España y en Europa, Editorial',
#  'Ariel, Barcelona, 1999, pp. 58-93.',
#  '9. Notes on Conflict and Distribution in J.M. Maravall (ed.) Dimensiones de la',
#  'Desigualdad, 2 vols., Fundación Argentaria, Madrid, 1999, vol. 1 pp. 45-69.',
#  '10. Regional Implications of the European Monetary Union (in Spanish) (with J.',
#  'Gual) in Seminario sobre la Introducción del Euro en la Comunidades',
#  'Autónomas Institut d’Estudis Econòmics, Generalitat de Catalunya, Barcelona,',
#  '1999, pp. 17-38.',
#  '11. Comment to H.K. Ryu and D.J. Slottje Parametric Approximations of the',
#  'Lorenz Curve in J. Silber (ed.) Handbook of Income Inequality Measurement,',
#  'Boston,Kluwer Academic Press, 1999, pp.312-314.',
#  '12. Interregional Inequality in Europe and in Spain,description and analysis (in',
#  'Spanish), in Growth and Regional Convergence in Europe and Spain (in',
#  'Spanish), 2 vols., Instituto de Análisis Económico, CSIC, y Fundación de',
#  'Economía Analítica, Barcelona, 1994, volume 2, pp. 13-84.',
#  '13. Core, Bounded Core and Efficiency in Overlapping Generations Economies, in',
#  'B. Dutta et al. (ed.), Theoretical Issues in Development Economics, Oxford',
#  'University Press, 1993, pp 247-262.',
#  '14. The Concept and Measurement of Polarization (in Spanish) with D. Ray, I',
#  'Simposio sobre Desigualdad y Distribución de la Renta y la Riqueza, Fundación',
#  'Argentaria, Madrid, 1993, vol. 2, pp. 23-49.',
#  '15. Trusting Fiat Money (in Spanish), in X. Calsamiglia and R. Marimon (eds),',
#  'Invitación a la Teoria Económica, Ed. Ariel, Barcelona, 1991, pp. 45-57.',
#  '16. Principles for the Reform of the Spanish Fiscal System for the Regional',
#  'Governments (in Spanish) (with X. Calsamiglia), in E. Aja (ed) Informe Pi i',
#  '6',
#  'Joan Esteban CV, September 2014',
#  'Sunyer sobre Comunidades Autónomas, 1990, Ed. Civitas, Barcelona, 1991, pp.',
#  '318-343.',
#  '17. The Economic Policy of Francoism,An Interpretation, in P. Preston (ed.) Spain',
#  'in Crisis, The Harvester Press, Hassocks, 1976, pp. 82-100. Spanish translation',
#  'España en Crisis, Fondo de Cultura Económica, Madrid, 1978 and Italian',
#  'translation Le Basi Autoritarie della Spagna Democratica, Rosenberg & Sellier,',
#  'Torino, 1978.',
#  '18. Inter-regional Analysis of the Spanish Industrial Growth (in Spanish)',
#  '(coauthor), Ponencias del VIIº Coloquio de la Asociación de Ciencia Regional de',
#  'Lengua Francesa, Ed. Moneda y Crédito, Madrid 1968, pp. 59-172.',
#  'EDITORIAL BOARDS',
#  'Economic Notes (1989-98), Economics of Governance (2006-  ) European',
#  'Journal of Political Economy (1985- 00, 03-), Hacienda Pública Española/Revista',
#  'de Economía Pública (2002- 2006), Journal of Income Inequality (2001-  ),',
#  'Journal of Public Economics (1993-97).',
#  'REFEREEING',
#  'American Economic Review, American Journal of Political Science, American',
#  'Political Science Review, Annales d’Économie et de Statistique, CICYT,',
#  'Econometrica, Economic Development and Cultural Change, Economics Letters,',
#  'Economic Notes, Economic Theory, European Journal of Political Economy,',
#  'German Statistical Review, Hacienda Pública Española/Revista de Economía',
#  'Pública, International Tax and Public Finance, Investigaciones Económicas,',
#  'International Economic Review, Journal of Economic Behavior and Organization,',
#  'Journal of Economic Theory, Journal of the European Economic Association,',
#  'Journal of Mathematical Economics, Journal of Public Economic Theory, Journal',
#  'of Public Economics, Journal of Theoretical Political Economy, Mathematical',
#  'Social Sciences, Moneda y Crédito, National Science Foundation, Rand Journal of',
#  'Economics, Regional Science and Urban Economics, Review of Economic Studies,',
#  'Review of Economics and Statistics, Review of Income and Wealth, Revista de',
#  'Economía Aplicada, Revista Española de Economía, Social Choice and Welfare.',
#  'AWARDS and DISTINCTIONS',
#  'Member of the E15 Initiative expert group on Envigorating Manufacturing,',
#  'ICTSD and World Economic Forum. May 2014-',
#  'Member of the Scientific Council of the Aix-Marseille School of Economics.',
#  'January 2013-     .',
#  'Secretary General of the International Economic Association (2011-2013)',
#  'Member of the Executive Council of the International Economic Association',
#  '(2005-2011) and (2014-    ).',
#  'Rey Jaime I laureate in Economics, 2007.',
#  'President-Elect (2005-2006) and President (2007-2009) of the Society for the',
#  'Study of Economic Inequality (ECINEQ)',
#  'President of the Spanish Economic Association (2002)',
#  'Premi Catalunya d’Economia, Societat Catalana d’Economia, Institut d’Estudis',
#  'Catalans, 1996.',
#  '7',
#  'Joan Esteban CV, September 2014',
#  '8']

# %%
len(lista)
# Out:
# 308

# %%
lines = []
indices = []
for i in lista:
    cont = 0
    poss = []
    f1 = ""
    f2 = ""
    idx = 0
    for j in cargos:
        if j in i and ',' in i:
            n = len(j)
            if n>cont:
                cont+=len(j)
                poss.append([i, j])
            if len(poss)>1:
                poss = [poss[-1]]
            inf1, inf2 = poss[0]
            f1 = inf1
            f2 = inf2
        else:
            if i not in indices:
                indices.append(i)
    lines.append([f1, f2])
    
cadena = "\n".join(indices)
f_text = open("{}_cadena.txt".format(nombre), "w")
f_text.write(cadena)
f_text.close()

lines = [i for i in lines if i!=["",""]]
for data in lines:
    places = []
    linea, cargo = data
    print("Linea a ser analizada:", "           >>>{}<<<\n".format(linea))
    info = [i.strip() for i in linea.split(",")]
    print(info, ">>>", cargo, "> (Cargo basado en la lista existente)")
    places = [i for i in inst if i in linea]
    lol = [i for i in places if i in info]
    lol2 = []
    for p in info:
        for q in places:
            if q in p:
                lol2.append(p)
    #print(places, "generic places")
    #print(lol, "lol")
    lol2 = list(set(lol2))
    print(lol, ">>> Instituciones dentro del registro")
    
    if len(lol) > 0:
        for t in lol:
            linea = linea.replace(t, "")
        #linea = linea.replace(cargo,"")
        #print(linea, ">>>", "linea filtrada")
    else:
        pass
        #print(linea, ">>>", "linea no filtrada")
    
    lista_filtrada = [i for i in linea.split(",") if i!=""]
    lista_filtrada = [i for i in lista_filtrada if i!=" "]
    lista_filtrada = [i.strip() for i in lista_filtrada]
    lista_cargo = [i for i in lista_filtrada if cargo in i]
    rw_cargos = ""
    print(lista_cargo, ">>>", "(Cargo hallado)")
    contt = 0
    for i in lista_cargo:
        if i not in cargos:
            contt+=1
    if contt>0:
        rw_cargos+="revisar/anadir cargo"
    else:
        rw_cargos+="0"
    lista_filtrada = [i for i in lista_filtrada if i not in lista_cargo]
    lista_anios = []
    for r in rango:
        for s in lista_filtrada:
            if r in s:
                lista_anios.append(s)
    lista_anios = list(set(lista_anios))
    print(lista_anios, ">>>", "years")
    lista_filtrada = [i for i in lista_filtrada if i not in lista_anios]
    lista_filtrada = [i for i in lista_filtrada if i not in lista_cargo]
    #print(lista_filtrada, "OJO OKO OJO OKO")
    
    if len(lista_filtrada) > 0:
        print(lista_filtrada, ">>>", "Instituciones no registradas")
    else:
        print(lista_filtrada, "Lista vacia: Instit. no halladas / Instit. filtradas correctamente")
    
    if len(lista_filtrada) > 0 and len(lol) > 0 and len(lista_anios) > 0:
        ins1 = "_".join(lol)
        ins2 = "_".join(lista_filtrada)
        ins3 = "{}_{}".format(ins1, ins2) # instituciones no registrada
        
        cargo = '_'.join(lista_cargo)
        
        categ = ""
        for k in categories:
            validar = categories[k]
            for rt in validar:
                if cargo in validar[rt]:
                    categ+=rt
        if len(categ)>0:
            print("Categoria:", categ)
        else:
            print("Categoria no existente")
            
        anio = "_".join(lista_anios)
        print("Linea a registrar:\n")
        
        linea = "{},{},{},{},{},{},revisar/anadir institucion,0\n".format(nombre,categ,cargo, ins3, anio,rw_cargos)
        print(linea)
        print()
        print("Condicion 1")
        print()
        file.write(linea)
        print("######################################################################################################################")
        
    elif len(lista_filtrada) == 0 and len(lol) == 0 and len(lista_anios) > 0:
        ins1 = "_".join(lol)
        ins2 = "_".join(lista_filtrada)
        ins3 = "{}_{}".format(ins1, ins2) # instituciones no registrada
        
        cargo = '_'.join(lista_cargo)
        
        categ = ""
        for k in categories:
            validar = categories[k]
            for rt in validar:
                if cargo in validar[rt]:
                    categ+=rt
        if len(categ)>0:
            print("Categoria:", categ)
        else:
            print("Categoria no existente")
        
        anio = "_".join(lista_anios)
        print("Linea a registrar:\n")
        
        linea = "{},{},{},{},{},{},revisar/anadir institucion,0\n".format(nombre,categ,cargo, ins3, anio,rw_cargos)
        print(linea)
        print()
        print("Condicion 2")
        print()
        file.write(linea)
        print("######################################################################################################################")
        
    elif len(lista_filtrada) > 0 and len(lol) == 0 and len(lista_anios) == 0:
        ins1 = "_".join(lol)
        ins2 = "_".join(lista_filtrada)
        ins3 = "{}_{}".format(ins1, ins2) # instituciones no registrada
        
        cargo = '_'.join(lista_cargo)
        
        categ = ""
        for k in categories:
            validar = categories[k]
            for rt in validar:
                if cargo in validar[rt]:
                    categ+=rt
        if len(categ)>0:
            print("Categoria:", categ)
        else:
            
            print("Categoria no existente")
        
        anio = "_".join(lista_anios)
        print("Linea a registrar:\n")
        
        linea = "{},{},{},{},{},{},0,revisar/anadir anio\n".format(nombre,categ,cargo, ins3, anio,rw_cargos)
        print(linea)
        print()
        print("Condicion 3")
        print()
        file.write(linea)
        print("######################################################################################################################")

    elif len(lista_filtrada) > 0 and len(lol) == 0 and len(lista_anios) > 0:
        ins1 = "_".join(lol)
        ins2 = "_".join(lista_filtrada)
        ins3 = "{}_{}".format(ins1, ins2) # instituciones no registrada
        
        cargo = '_'.join(lista_cargo)
        
        categ = ""
        for k in categories:
            validar = categories[k]
            for rt in validar:
                if cargo in validar[rt]:
                    categ+=rt
        if len(categ)>0:
            print("Categoria:", categ)
        else:
            print("Categoria no existente")
        
        anio = "_".join(lista_anios)
        print("Linea a registrar:\n")
        
        linea = "{},{},{},{},{},{},revisar/anadir intitucion,0\n".format(nombre,categ,cargo, ins3, anio,rw_cargos)
        print(linea)
        print()
        print("Condicion 4")
        print()
        file.write(linea)
        print("######################################################################################################################")
        
    elif len(lista_filtrada) == 0 and len(lol) > 0 and len(lista_anios) > 0:
        ins1 = "_".join(lol)
        #ins2 = "-".join(lista_filtrada)
        #ins3 = "{}-{}".format(ins1, ins2) # instituciones no registrada
        
        cargo = '_'.join(lista_cargo)
        
        categ = ""
        for k in categories:
            validar = categories[k]
            for rt in validar:
                if cargo in validar[rt]:
                    categ+=rt
        if len(categ)>0:
            print("Categoria:", categ)
        else:
            print("Categoria no existente")
        
        anio = "_".join(lista_anios)
        print("Linea a registrar:\n")
        
        linea = "{},{},{},{},{},{},0,0\n".format(nombre,categ,cargo, ins1, anio,rw_cargos)
        print(linea)
        print()
        print("Condicion 5")
        print()
        file.write(linea)
        print("######################################################################################################################")
        
    elif len(lista_filtrada) == 0 and len(lol) > 0 and len(lista_anios) == 0:
        ins1 = "_".join(lol)
        ins2 = "_".join(lista_filtrada)
        ins3 = "{}_{}".format(ins1, ins2) # instituciones no registrada
        
        cargo = '_'.join(lista_cargo)
        
        categ = ""
        for k in categories:
            validar = categories[k]
            for rt in validar:
                if cargo in validar[rt]:
                    categ+=rt
        if len(categ)>0:
            print("Categoria:", categ)
        else:
            print("Categoria no existente")
        
        anio = "_".join(lista_anios)
        print("Linea a registrar:\n")
        
        linea = "{},{},{},{},{},{},0,revisar/anadir anio\n".format(nombre,categ,cargo, ins3, anio,rw_cargos)
        print(linea)
        print()
        print("Condicion 6")
        print()
        file.write(linea)
        print("######################################################################################################################")

    elif len(lista_filtrada) > 0 and len(lol) > 0 and len(lista_anios) == 0:
        ins1 = "_".join(lol)
        ins2 = "_".join(lista_filtrada)
        ins3 = "{}_{}".format(ins1, ins2) # instituciones no registrada
        
        cargo = '_'.join(lista_cargo)
        
        categ = ""
        for k in categories:
            validar = categories[k]
            for rt in validar:
                if cargo in validar[rt]:
                    categ+=rt
        if len(categ)>0:
            print("Categoria:", categ)
        else:
            print("Categoria no existente")
        
        anio = "_".join(lista_anios)
        print("Linea a registrar:\n")
        
        linea = "{},{},{},{},{},{},0,revisar/anadir anio\n".format(nombre,categ,cargo, ins3, anio,rw_cargos)
        print(linea)
        print()
        print("Condicion 7")
        print()
        file.write(linea)
        print("######################################################################################################################")
        
    elif len(lista_filtrada) == 0 and len(lol) == 0 and len(lista_anios) == 0:
        ins1 = "_".join(lol)
        ins2 = "_".join(lista_filtrada)
        ins3 = "{}_{}".format(ins1, ins2) # instituciones no registrada
        
        cargo = '_'.join(lista_cargo)
        anio = "_".join(lista_anios)
        
        linea = "{},{},{},{},{},0,revisar/anadir anio\n".format(nombre,cargo, ins3, anio,rw_cargos)
        print("\nWARNING: Linea a agrear vacia/no valida. Se sugiere revisar los datos.\n")
        print("Condicion 8")
        print()
        #file.write(linea)
        print("######################################################################################################################")
    else:
        print("######################################################################################################################")
        print("LA LINEA NO FUE CREADA. VERIFICAR ERROR")
        print("######################################################################################################################")
# Out:
# Linea a ser analizada:            >>>Professor Associat, Universitat Pompeu Fabra<<<
#
# ['Professor Associat', 'Universitat Pompeu Fabra'] >>> Professor > (Cargo basado en la lista existente)
# ['Universitat Pompeu Fabra'] >>> Instituciones dentro del registro
# ['Professor Associat'] >>> (Cargo hallado)
# [] >>> years
# [] Lista vacia: Instit. no halladas / Instit. filtradas correctamente
# Categoria no existente
# Linea a registrar:
#
# joan,,Professor Associat,Universitat Pompeu Fabra_,,revisar/anadir cargo,0,revisar/anadir anio
#
#
# Condicion 6
#
# ######################################################################################################################
# Linea a ser analizada:            >>>Professor, Universitat Autònoma de Barcelona.<<<
#
# ['Professor', 'Universitat Autònoma de Barcelona.'] >>> Professor > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ['Professor'] >>> (Cargo hallado)
# [] >>> years
# ['Universitat Autònoma de Barcelona.'] >>> Instituciones no registradas
# Categoria: professor
# Linea a registrar:
#
# joan,professor,Professor,_Universitat Autònoma de Barcelona.,,0,0,revisar/anadir anio
#
#
# Condicion 3
#
# ######################################################################################################################
# Linea a ser analizada:            >>>Associate Professor, Universitat Autònoma de Barcelona.<<<
#
# ['Associate Professor', 'Universitat Autònoma de Barcelona.'] >>> Associate Professor > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ['Associate Professor'] >>> (Cargo hallado)
# [] >>> years
# ['Universitat Autònoma de Barcelona.'] >>> Instituciones no registradas
# Categoria: professor
# Linea a registrar:
#
# joan,professor,Associate Professor,_Universitat Autònoma de Barcelona.,,0,0,revisar/anadir anio
#
#
# Condicion 3
#
# ######################################################################################################################
# Linea a ser analizada:            >>>Assistant Professor, Universitat Autònoma de Barcelona.<<<
#
# ['Assistant Professor', 'Universitat Autònoma de Barcelona.'] >>> Assistant Professor > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ['Assistant Professor'] >>> (Cargo hallado)
# [] >>> years
# ['Universitat Autònoma de Barcelona.'] >>> Instituciones no registradas
# Categoria: professor
# Linea a registrar:
#
# joan,professor,Assistant Professor,_Universitat Autònoma de Barcelona.,,0,0,revisar/anadir anio
#
#
# Condicion 3
#
# ######################################################################################################################
# Linea a ser analizada:            >>>Assistant Professor, Universitat Autònoma de Barcelona.<<<
#
# ['Assistant Professor', 'Universitat Autònoma de Barcelona.'] >>> Assistant Professor > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ['Assistant Professor'] >>> (Cargo hallado)
# [] >>> years
# ['Universitat Autònoma de Barcelona.'] >>> Instituciones no registradas
# Categoria: professor
# Linea a registrar:
#
# joan,professor,Assistant Professor,_Universitat Autònoma de Barcelona.,,0,0,revisar/anadir anio
#
#
# Condicion 3
#
# ######################################################################################################################
# Linea a ser analizada:            >>>Teaching Assistant, Universitat Autònoma de Barcelona.<<<
#
# ['Teaching Assistant', 'Universitat Autònoma de Barcelona.'] >>> Teaching Assistant > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ['Teaching Assistant'] >>> (Cargo hallado)
# [] >>> years
# ['Universitat Autònoma de Barcelona.'] >>> Instituciones no registradas
# Categoria: teaching
# Linea a registrar:
#
# joan,teaching,Teaching Assistant,_Universitat Autònoma de Barcelona.,,0,0,revisar/anadir anio
#
#
# Condicion 3
#
# ######################################################################################################################
# Linea a ser analizada:            >>>Teaching Assistant, Universidad de Barcelona.<<<
#
# ['Teaching Assistant', 'Universidad de Barcelona.'] >>> Teaching Assistant > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ['Teaching Assistant'] >>> (Cargo hallado)
# [] >>> years
# ['Universidad de Barcelona.'] >>> Instituciones no registradas
# Categoria: teaching
# Linea a registrar:
#
# joan,teaching,Teaching Assistant,_Universidad de Barcelona.,,0,0,revisar/anadir anio
#
#
# Condicion 3
#
# ######################################################################################################################
# Linea a ser analizada:            >>>2001-06,Director of the Institut d'Anàlisi Econòmica, CSIC.<<<
#
# ['2001-06', "Director of the Institut d'Anàlisi Econòmica", 'CSIC.'] >>> Director > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ["Director of the Institut d'Anàlisi Econòmica"] >>> (Cargo hallado)
# ['2001-06'] >>> years
# ['CSIC.'] >>> Instituciones no registradas
# Categoria no existente
# Linea a registrar:
#
# joan,,Director of the Institut d'Anàlisi Econòmica,_CSIC.,2001-06,revisar/anadir cargo,revisar/anadir intitucion,0
#
#
# Condicion 4
#
# ######################################################################################################################
# Linea a ser analizada:            >>>1990-96,Member of the Research Council of the European University Institute.<<<
#
# ['1990-96', 'Member of the Research Council of the European University Institute.'] >>> Member > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ['Member of the Research Council of the European University Institute.'] >>> (Cargo hallado)
# ['1990-96'] >>> years
# [] Lista vacia: Instit. no halladas / Instit. filtradas correctamente
# Categoria no existente
# Linea a registrar:
#
# joan,,Member of the Research Council of the European University Institute.,_,1990-96,revisar/anadir cargo,revisar/anadir institucion,0
#
#
# Condicion 2
#
# ######################################################################################################################
# Linea a ser analizada:            >>>1992-93,Member of the expert group in Economic, Social and Human Sciences of<<<
#
# ['1992-93', 'Member of the expert group in Economic', 'Social and Human Sciences of'] >>> Member > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ['Member of the expert group in Economic'] >>> (Cargo hallado)
# ['1992-93'] >>> years
# ['Social and Human Sciences of'] >>> Instituciones no registradas
# Categoria no existente
# Linea a registrar:
#
# joan,,Member of the expert group in Economic,_Social and Human Sciences of,1992-93,revisar/anadir cargo,revisar/anadir intitucion,0
#
#
# Condicion 4
#
# ######################################################################################################################
# Linea a ser analizada:            >>>the Human Capital and Mobility programme, Directorate-General for<<<
#
# ['the Human Capital and Mobility programme', 'Directorate-General for'] >>> Director > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ['Directorate-General for'] >>> (Cargo hallado)
# [] >>> years
# ['the Human Capital and Mobility programme'] >>> Instituciones no registradas
# Categoria no existente
# Linea a registrar:
#
# joan,,Directorate-General for,_the Human Capital and Mobility programme,,revisar/anadir cargo,0,revisar/anadir anio
#
#
# Condicion 3
#
# ######################################################################################################################
# Linea a ser analizada:            >>>1989-91,Director of the Institut d'Anàlisi Econòmica, CSIC.<<<
#
# ['1989-91', "Director of the Institut d'Anàlisi Econòmica", 'CSIC.'] >>> Director > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ["Director of the Institut d'Anàlisi Econòmica"] >>> (Cargo hallado)
# ['1989-91'] >>> years
# ['CSIC.'] >>> Instituciones no registradas
# Categoria no existente
# Linea a registrar:
#
# joan,,Director of the Institut d'Anàlisi Econòmica,_CSIC.,1989-91,revisar/anadir cargo,revisar/anadir intitucion,0
#
#
# Condicion 4
#
# ######################################################################################################################
# Linea a ser analizada:            >>>1987-89,Vice-Director of the Institut d'Anàlisi Econòmica, CSIC.<<<
#
# ['1987-89', "Vice-Director of the Institut d'Anàlisi Econòmica", 'CSIC.'] >>> Director > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ["Vice-Director of the Institut d'Anàlisi Econòmica"] >>> (Cargo hallado)
# ['1987-89'] >>> years
# ['CSIC.'] >>> Instituciones no registradas
# Categoria no existente
# Linea a registrar:
#
# joan,,Vice-Director of the Institut d'Anàlisi Econòmica,_CSIC.,1987-89,revisar/anadir cargo,revisar/anadir intitucion,0
#
#
# Condicion 4
#
# ######################################################################################################################
# Linea a ser analizada:            >>>1985-87,Department Chairman.<<<
#
# ['1985-87', 'Department Chairman.'] >>> Chairman > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ['Department Chairman.'] >>> (Cargo hallado)
# ['1985-87'] >>> years
# [] Lista vacia: Instit. no halladas / Instit. filtradas correctamente
# Categoria no existente
# Linea a registrar:
#
# joan,,Department Chairman.,_,1985-87,revisar/anadir cargo,revisar/anadir institucion,0
#
#
# Condicion 2
#
# ######################################################################################################################
# Linea a ser analizada:            >>>1978-85,Director of the Graduate Program.<<<
#
# ['1978-85', 'Director of the Graduate Program.'] >>> Director > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ['Director of the Graduate Program.'] >>> (Cargo hallado)
# ['1978-85'] >>> years
# [] Lista vacia: Instit. no halladas / Instit. filtradas correctamente
# Categoria no existente
# Linea a registrar:
#
# joan,,Director of the Graduate Program.,_,1978-85,revisar/anadir cargo,revisar/anadir institucion,0
#
#
# Condicion 2
#
# ######################################################################################################################
# Linea a ser analizada:            >>>Member of the E15 Initiative expert group on Envigorating Manufacturing,<<<
#
# ['Member of the E15 Initiative expert group on Envigorating Manufacturing', ''] >>> Member > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ['Member of the E15 Initiative expert group on Envigorating Manufacturing'] >>> (Cargo hallado)
# [] >>> years
# [] Lista vacia: Instit. no halladas / Instit. filtradas correctamente
#
# WARNING: Linea a agrear vacia/no valida. Se sugiere revisar los datos.
#
# Condicion 8
#
# ######################################################################################################################
# Linea a ser analizada:            >>>Rey Jaime I laureate in Economics, 2007.<<<
#
# ['Rey Jaime I laureate in Economics', '2007.'] >>> laurea > (Cargo basado en la lista existente)
# [] >>> Instituciones dentro del registro
# ['Rey Jaime I laureate in Economics'] >>> (Cargo hallado)
# ['2007.'] >>> years
# [] Lista vacia: Instit. no halladas / Instit. filtradas correctamente
# Categoria no existente
# Linea a registrar:
#
# joan,,Rey Jaime I laureate in Economics,_,2007.,revisar/anadir cargo,revisar/anadir institucion,0
#
#
# Condicion 2
#
# ######################################################################################################################

# %%
file.close()

# %%
y = search_dates("1999 - 2005")
y
# Out:
# [('1999', datetime.datetime(1999, 1, 15, 0, 0)),
#  ('2005', datetime.datetime(2005, 1, 15, 0, 0))]

# %%
df = pd.read_csv("john2.csv", encoding = "ISO-8859-1")

# %%
df
# Out:
#    nombre   categoria                                              cargo  \
# 0    joan         NaN                                 Professor Associat
# 1    joan  employment                                          Professor
# 2    joan  employment                                Associate Professor
# 3    joan  employment                                Assistant Professor
# 4    joan  employment                                Assistant Professor
# 5    joan  employment                                 Teaching Assistant
# 6    joan  employment                                 Teaching Assistant
# 7    joan         NaN       Director of the Institut d'Anàlisi Econòmica
# 8    joan         NaN  Member of the Research Council of the European...
# 9    joan         NaN             Member of the expert group in Economic
# 10   joan         NaN                            Directorate-General for
# 11   joan         NaN       Director of the Institut d'Anàlisi Econòmica
# 12   joan         NaN  Vice-Director of the Institut d'Anàlisi Econòmica
# 13   joan         NaN                               Department Chairman.
# 14   joan         NaN                  Director of the Graduate Program.
# 15   joan         NaN                  Rey Jaime I laureate in Economics
#
#                                     instucion     year         descrip-cargo  \
# 0                   Universitat Pompeu Fabra_      NaN  revisar/anadir cargo
# 1         _Universitat Autònoma de Barcelona.      NaN                     0
# 2         _Universitat Autònoma de Barcelona.      NaN                     0
# 3         _Universitat Autònoma de Barcelona.      NaN                     0
# 4         _Universitat Autònoma de Barcelona.      NaN                     0
# 5         _Universitat Autònoma de Barcelona.      NaN                     0
# 6                  _Universidad de Barcelona.      NaN                     0
# 7                                      _CSIC.  2001-06  revisar/anadir cargo
# 8                                           _  1990-96  revisar/anadir cargo
# 9               _Social and Human Sciences of  1992-93  revisar/anadir cargo
# 10  _the Human Capital and Mobility programme      NaN  revisar/anadir cargo
# 11                                     _CSIC.  1989-91  revisar/anadir cargo
# 12                                     _CSIC.  1987-89  revisar/anadir cargo
# 13                                          _  1985-87  revisar/anadir cargo
# 14                                          _  1978-85  revisar/anadir cargo
# 15                                          _    2007.  revisar/anadir cargo
#
#             descrip-intitucion         descrip-year
# 0                            0  revisar/anadir anio
# 1                            0  revisar/anadir anio
# 2                            0  revisar/anadir anio
# 3                            0  revisar/anadir anio
# 4                            0  revisar/anadir anio
# 5                            0  revisar/anadir anio
# 6                            0  revisar/anadir anio
# 7    revisar/anadir intitucion                    0
# 8   revisar/anadir institucion                    0
# 9    revisar/anadir intitucion                    0
# 10                           0  revisar/anadir anio
# 11   revisar/anadir intitucion                    0
# 12   revisar/anadir intitucion                    0
# 13  revisar/anadir institucion                    0
# 14  revisar/anadir institucion                    0
# 15  revisar/anadir institucion                    0

# %%
df[df.cargo=="Teaching Assistant"]
# Out:
#   nombre               cargo                            instucion year  \
# 5   joan  Teaching Assistant  _Universitat Autònoma de Barcelona.  NaN
# 6   joan  Teaching Assistant           _Universidad de Barcelona.  NaN
#
#   descrip-cargo descrip-intitucion         descrip-year
# 5             0                  0  revisar/anadir anio
# 6             0                  0  revisar/anadir anio

# %%
cargos.sort()
cargos
# Out:
# ['A.b.',
#  'Academic Visits',
#  'Academic visits',
#  'Adjunct Professor',
#  'Adjunct Research Professor',
#  'Adjunct professor',
#  'Adjunct research professor',
#  'Advanced Grant',
#  'Advanced grant',
#  'Affiliated Professor',
#  'Affiliated professor',
#  'Assistant Editor',
#  'Assistant Professor',
#  'Assistant Professor In Economics',
#  'Assistant editor',
#  'Assistant professor',
#  'Assistant professor in economics',
#  'Associate Director',
#  'Associate Editor',
#  'Associate Faculty',
#  'Associate Head',
#  'Associate Professor',
#  'Associate director',
#  'Associate editor',
#  'Associate faculty',
#  'Associate head',
#  'Associate professor',
#  'Award',
#  'B.a.',
#  'B.sc',
#  'Bachelor',
#  'Board Member',
#  'Board member',
#  'Book Review Editor',
#  'Book review editor',
#  'Booth Professor',
#  'Booth professor',
#  'Chair',
#  'Chairman',
#  'Co-Director',
#  'Co-director',
#  'Co-editor',
#  'Computer Science Magnet',
#  'Computer science magnet',
#  'Council Member',
#  'Council Member Diplom',
#  'Council member',
#  'Council member diplom',
#  'Directeur',
#  'Director',
#  'Editor-in-chief',
#  'Editorial Board',
#  'Editorial board',
#  'Elected Member',
#  'Elected member',
#  'External Examiner',
#  'External examiner',
#  'Faculty Research Fellow',
#  'Faculty research fellow',
#  'Fellow',
#  'Fellowship',
#  'Former Associate Editor',
#  'Former associate editor',
#  'Full Professor',
#  'Full professor',
#  'Gastprofessor',
#  'Grant',
#  'Guest Editor',
#  'Guest editor',
#  'Instructor',
#  'International Research Fellow',
#  'International research fellow',
#  'Invited Editor',
#  'Invited editor',
#  'Laurea',
#  'Lecturer',
#  'M.Sc',
#  'M.a',
#  'M.a.',
#  'M.sc',
#  'MSc',
#  'Member',
#  'Mphil',
#  'Msc',
#  'Panel Member',
#  'Panel member',
#  'Ph. D.',
#  'Ph. d.',
#  'Ph.d',
#  'Ph.d.',
#  'Postdoctoral Researcher',
#  'Postdoctoral researcher',
#  'Prize',
#  'Professor',
#  'Professor Of Economics',
#  'Professor of economics',
#  'Project Advisor',
#  'Project advisor',
#  'Research Assistant',
#  'Research Associate',
#  'Research Chair',
#  'Research Fellow',
#  'Research Fellowship',
#  'Research Professor',
#  'Research Visitor',
#  'Research assistant',
#  'Research associate',
#  'Research chair',
#  'Research fellow',
#  'Research fellowship',
#  'Research professor',
#  'Research visitor',
#  'S.m.',
#  'Scholarship',
#  'Senior Lecturer',
#  'Senior lecturer',
#  'Teaching Assistant',
#  'Teaching assistant',
#  'University Professor',
#  'University professor',
#  'Visiting Assistant Professor',
#  'Visiting Associate Professor',
#  'Visiting Fellow',
#  'Visiting Postdoctoral Researcher',
#  'Visiting Professor',
#  'Visiting Research Faculty',
#  'Visiting Research Student',
#  'Visiting Scholar',
#  'Visiting Student',
#  'Visiting assistant professor',
#  'Visiting associate professor',
#  'Visiting fellow',
#  'Visiting postdoctoral researcher',
#  'Visiting professor',
#  'Visiting research faculty',
#  'Visiting research student',
#  'Visiting scholar',
#  'Visiting student',
#  'Visitor',
#  'a.b.',
#  'academic visits',
#  'adjunct professor',
#  'adjunct research professor',
#  'advanced grant',
#  'affiliated professor',
#  'assistant editor',
#  'assistant professor',
#  'assistant professor in economics',
#  'associate director',
#  'associate editor',
#  'associate faculty',
#  'associate head',
#  'associate professor',
#  'award',
#  'b.a.',
#  'b.sc',
#  'bachelor',
#  'board member',
#  'book review editor',
#  'booth professor',
#  'chair',
#  'chairman',
#  'co-director',
#  'co-editor',
#  'computer science magnet',
#  'council member',
#  'council member diplom',
#  'directeur',
#  'director',
#  'editor-in-chief',
#  'editorial board',
#  'elected member',
#  'external examiner',
#  'faculty research fellow',
#  'fellow',
#  'fellowship',
#  'former associate editor',
#  'full professor',
#  'gastprofessor',
#  'grant',
#  'guest editor',
#  'instructor',
#  'international research fellow',
#  'invited editor',
#  'laurea',
#  'lecturer',
#  'm.a',
#  'm.a.',
#  'm.sc',
#  'member',
#  'mphil',
#  'msc',
#  'msc',
#  'panel member',
#  'ph. d.',
#  'ph.d',
#  'ph.d.',
#  'postdoctoral researcher',
#  'prize',
#  'professor',
#  'professor of economics',
#  'project advisor',
#  'research assistant',
#  'research associate',
#  'research chair',
#  'research fellow',
#  'research fellowship',
#  'research professor',
#  'research visitor',
#  's.m.',
#  'scholarship',
#  'senior lecturer',
#  'teaching assistant',
#  'university professor',
#  'visiting assistant professor',
#  'visiting fellow',
#  'visiting postdoctoral researcher',
#  'visiting professor',
#  'visiting research faculty',
#  'visiting research student',
#  'visiting scholar',
#  'visiting student',
#  'visitor']

# %%
for k in categories:
    validar = categories[k]
    for cargo in cargos:
        if cargo in validar:
            print(cargo, ">>>", k)
# Out:
# A.b. >>> education
# B.a. >>> education
# B.sc >>> education
# Bachelor >>> education
# M.Sc >>> education
# M.a >>> education
# M.a. >>> education
# M.sc >>> education
# MSc >>> education
# Msc >>> education
# Ph. D. >>> education
# Ph. d. >>> education
# Ph.d >>> education
# Ph.d. >>> education
# S.m. >>> education
# a.b. >>> education
# b.a. >>> education
# b.sc >>> education
# bachelor >>> education
# m.a >>> education
# m.a. >>> education
# m.sc >>> education
# msc >>> education
# msc >>> education
# ph. d. >>> education
# ph.d >>> education
# ph.d. >>> education
# s.m. >>> education
# Advanced Grant >>> honors and awards (Grants, Fellowships and Patents)
# Advanced grant >>> honors and awards (Grants, Fellowships and Patents)
# Award >>> honors and awards (Grants, Fellowships and Patents)
# Board Member >>> honors and awards (Grants, Fellowships and Patents)
# Board member >>> honors and awards (Grants, Fellowships and Patents)
# Council Member >>> honors and awards (Grants, Fellowships and Patents)
# Council Member Diplom >>> honors and awards (Grants, Fellowships and Patents)
# Council member >>> honors and awards (Grants, Fellowships and Patents)
# Council member diplom >>> honors and awards (Grants, Fellowships and Patents)
# Elected Member >>> honors and awards (Grants, Fellowships and Patents)
# Elected member >>> honors and awards (Grants, Fellowships and Patents)
# Faculty Research Fellow >>> honors and awards (Grants, Fellowships and Patents)
# Faculty research fellow >>> honors and awards (Grants, Fellowships and Patents)
# Fellow >>> honors and awards (Grants, Fellowships and Patents)
# Fellowship >>> honors and awards (Grants, Fellowships and Patents)
# Grant >>> honors and awards (Grants, Fellowships and Patents)
# International Research Fellow >>> honors and awards (Grants, Fellowships and Patents)
# International research fellow >>> honors and awards (Grants, Fellowships and Patents)
# Member >>> honors and awards (Grants, Fellowships and Patents)
# Panel Member >>> honors and awards (Grants, Fellowships and Patents)
# Panel member >>> honors and awards (Grants, Fellowships and Patents)
# Prize >>> honors and awards (Grants, Fellowships and Patents)
# Research Fellow >>> honors and awards (Grants, Fellowships and Patents)
# Research Fellowship >>> honors and awards (Grants, Fellowships and Patents)
# Research fellow >>> honors and awards (Grants, Fellowships and Patents)
# Research fellowship >>> honors and awards (Grants, Fellowships and Patents)
# Visiting Fellow >>> honors and awards (Grants, Fellowships and Patents)
# Visiting fellow >>> honors and awards (Grants, Fellowships and Patents)
# advanced grant >>> honors and awards (Grants, Fellowships and Patents)
# award >>> honors and awards (Grants, Fellowships and Patents)
# board member >>> honors and awards (Grants, Fellowships and Patents)
# council member >>> honors and awards (Grants, Fellowships and Patents)
# council member diplom >>> honors and awards (Grants, Fellowships and Patents)
# elected member >>> honors and awards (Grants, Fellowships and Patents)
# faculty research fellow >>> honors and awards (Grants, Fellowships and Patents)
# fellow >>> honors and awards (Grants, Fellowships and Patents)
# fellowship >>> honors and awards (Grants, Fellowships and Patents)
# grant >>> honors and awards (Grants, Fellowships and Patents)
# international research fellow >>> honors and awards (Grants, Fellowships and Patents)
# member >>> honors and awards (Grants, Fellowships and Patents)
# panel member >>> honors and awards (Grants, Fellowships and Patents)
# prize >>> honors and awards (Grants, Fellowships and Patents)
# research fellow >>> honors and awards (Grants, Fellowships and Patents)
# research fellowship >>> honors and awards (Grants, Fellowships and Patents)
# visiting fellow >>> honors and awards (Grants, Fellowships and Patents)
# Research Assistant >>> research experience
# Research Associate >>> research experience
# Research Chair >>> research experience
# Research Professor >>> research experience
# Research Visitor >>> research experience
# Research assistant >>> research experience
# Research associate >>> research experience
# Research chair >>> research experience
# Research professor >>> research experience
# Research visitor >>> research experience
# research assistant >>> research experience
# research associate >>> research experience
# research chair >>> research experience
# research professor >>> research experience
# research visitor >>> research experience
# Adjunct Professor >>> employment
# Adjunct Research Professor >>> employment
# Adjunct professor >>> employment
# Adjunct research professor >>> employment
# Affiliated Professor >>> employment
# Affiliated professor >>> employment
# Assistant Professor >>> employment
# Assistant Professor In Economics >>> employment
# Assistant professor >>> employment
# Assistant professor in economics >>> employment
# Associate Director >>> employment
# Associate Editor >>> employment
# Associate Faculty >>> employment
# Associate Head >>> employment
# Associate Professor >>> employment
# Associate director >>> employment
# Associate editor >>> employment
# Associate faculty >>> employment
# Associate head >>> employment
# Associate professor >>> employment
# Booth Professor >>> employment
# Booth professor >>> employment
# Chair >>> employment
# Chairman >>> employment
# Co-Director >>> employment
# Co-director >>> employment
# Directeur >>> employment
# Director >>> employment
# External examiner >>> employment
# Full Professor >>> employment
# Full professor >>> employment
# Lecturer >>> employment
# Professor >>> employment
# Professor Of Economics >>> employment
# Professor of economics >>> employment
# Senior Lecturer >>> employment
# Senior lecturer >>> employment
# Teaching Assistant >>> employment
# Teaching assistant >>> employment
# University Professor >>> employment
# University professor >>> employment
# Visiting Assistant Professor >>> employment
# Visiting Associate Professor >>> employment
# Visiting Postdoctoral Researcher >>> employment
# Visiting Professor >>> employment
# Visiting Research Faculty >>> employment
# Visiting Research Student >>> employment
# Visiting Scholar >>> employment
# Visiting Student >>> employment
# Visiting assistant professor >>> employment
# Visiting associate professor >>> employment
# Visiting postdoctoral researcher >>> employment
# Visiting professor >>> employment
# Visiting research faculty >>> employment
# Visiting research student >>> employment
# Visiting scholar >>> employment
# Visiting student >>> employment
# adjunct professor >>> employment
# adjunct research professor >>> employment
# affiliated professor >>> employment
# assistant professor >>> employment
# assistant professor in economics >>> employment
# associate director >>> employment
# associate editor >>> employment
# associate faculty >>> employment
# associate head >>> employment
# associate professor >>> employment
# booth professor >>> employment
# chair >>> employment
# chairman >>> employment
# co-director >>> employment
# directeur >>> employment
# director >>> employment
# external examiner >>> employment
# full professor >>> employment
# lecturer >>> employment
# professor >>> employment
# professor of economics >>> employment
# senior lecturer >>> employment
# teaching assistant >>> employment
# university professor >>> employment
# visiting assistant professor >>> employment
# visiting postdoctoral researcher >>> employment
# visiting professor >>> employment
# visiting research faculty >>> employment
# visiting research student >>> employment
# visiting scholar >>> employment
# visiting student >>> employment
# Assistant Editor >>> editorial service
# Assistant editor >>> editorial service
# Book Review Editor >>> editorial service
# Book review editor >>> editorial service
# Co-editor >>> editorial service
# Editor-in-chief >>> editorial service
# Editorial Board >>> editorial service
# Editorial board >>> editorial service
# Former Associate Editor >>> editorial service
# Former associate editor >>> editorial service
# Guest Editor >>> editorial service
# Guest editor >>> editorial service
# Invited Editor >>> editorial service
# Invited editor >>> editorial service
# assistant editor >>> editorial service
# book review editor >>> editorial service
# co-editor >>> editorial service
# editor-in-chief >>> editorial service
# editorial board >>> editorial service
# former associate editor >>> editorial service
# guest editor >>> editorial service
# invited editor >>> editorial service
# Academic Visits >>> other experince
# Academic visits >>> other experince
# Computer Science Magnet >>> other experince
# Computer science magnet >>> other experince
# External Examiner >>> other experince
# Gastprofessor >>> other experince
# Instructor >>> other experince
# Laurea >>> other experince
# Mphil >>> other experince
# Postdoctoral Researcher >>> other experince
# Postdoctoral researcher >>> other experince
# Project Advisor >>> other experince
# Project advisor >>> other experince
# Scholarship >>> other experince
# Visitor >>> other experince
# academic visits >>> other experince
# computer science magnet >>> other experince
# gastprofessor >>> other experince
# instructor >>> other experince
# laurea >>> other experince
# mphil >>> other experince
# postdoctoral researcher >>> other experince
# project advisor >>> other experince
# scholarship >>> other experince
# visitor >>> other experince

# %%
categories = {'education':['A.b.', 'a.b.', 'B.a.', 'b.a.', 'b.sc', 'B.sc', 'Bachelor', 'bachelor', 'M.Sc', 'M.a', 'M.a.', 'M.sc', 'm.a', 'm.a.', 'msc', 'm.sc', 'MSc', 'Msc', 'Ph. D.', 'Ph. d.', 'Ph.d', 'Ph.d.', 'ph. d.', 'ph.d', 'ph.d.', 'S.m.', 's.m.'],
             'honors and awards (Grants, Fellowships and Patents)':['Advanced Grant', 'Advanced grant', 'Grant', 'advanced grant', 'grant','Faculty Research Fellow', 'Faculty research fellow', 'Fellow', 'Fellowship', 'International Research Fellow', 'International research fellow', 'prize','Research Fellow', 'Research Fellowship', 'Research fellow', 'Research fellowship', 'Visiting Fellow', 'Visiting fellow', 'faculty research fellow', 'fellow', 'fellowship', 'international research fellow', 'research fellow', 'research fellowship', 'visiting fellow','Award', 'award','Prize','Board Member', 'Board member', 'Council Member', 'Council Member Diplom', 'Council member', 'Council member diplom', 'Elected Member', 'Elected member', 'Member', 'Panel Member', 'Panel member', 'board member', 'council member', 'council member diplom', 'elected member', 'member', 'panel member'],
             'research experience':['Research Assistant', 'Research Associate', 'Research Chair', 'Research Professor', 'Research Visitor', 'Research assistant', 'Research associate', 'Research chair', 'Research professor', 'Research visitor', 'research assistant', 'research associate', 'research chair', 'research professor', 'research visitor'],
             'employment':['External examiner', 'external examiner', 'Lecturer', 'Senior Lecturer', 'Senior lecturer', 'lecturer', 'senior lecturer','Directeur', 'directeur','Teaching Assistant', 'Teaching assistant', 'teaching assistant','Associate Director', 'Associate Editor', 'Associate Faculty', 'Associate Head', 'Associate Professor', 'Associate director', 'Associate editor', 'Associate faculty', 'Associate head', 'Visiting Assistant Professor', 'Visiting Associate Professor', 'Visiting Postdoctoral Researcher', 'Visiting Professor', 'Visiting Research Faculty', 'Visiting Research Student', 'Visiting Scholar', 'Visiting Student', 'Visiting assistant professor', 'Visiting associate professor', 'Visiting postdoctoral researcher', 'Visiting professor', 'Visiting research faculty', 'Visiting research student', 'Visiting scholar', 'Visiting student', 'associate director', 'associate editor', 'associate faculty', 'associate head', 'associate professor', 'visiting assistant professor', 'visiting postdoctoral researcher', 'visiting professor', 'visiting research faculty', 'visiting research student', 'visiting scholar', 'visiting student','Adjunct Professor', 'Adjunct Research Professor', 'Adjunct professor', 'Adjunct research professor', 'Affiliated Professor', 'Affiliated professor', 'Assistant Professor', 'Assistant Professor In Economics', 'Assistant professor', 'Assistant professor in economics', 'Associate professor', 'Booth Professor', 'Booth professor', 'Full Professor', 'Full professor', 'Professor', 'Professor Of Economics', 'Professor of economics', 'University Professor', 'University professor', 'adjunct professor', 'adjunct research professor', 'affiliated professor', 'assistant professor', 'assistant professor in economics', 'booth professor', 'full professor', 'professor', 'professor of economics', 'university professor','Chair', 'Chairman', 'chair', 'chairman','Co-Director', 'Co-director', 'Director', 'co-director', 'director'],
             'editorial service':['Assistant Editor', 'Assistant editor', 'Book Review Editor', 'Book review editor', 'Co-editor', 'Editor-in-chief', 'Editorial Board', 'Editorial board', 'Former Associate Editor', 'Former associate editor', 'Guest Editor', 'Guest editor', 'Invited Editor', 'Invited editor', 'assistant editor', 'book review editor', 'co-editor', 'editor-in-chief', 'editorial board', 'former associate editor', 'guest editor', 'invited editor'],
             'other experince':['Academic Visits', 'Academic visits', 'Computer Science Magnet', 'Computer science magnet', 'External Examiner', 'Gastprofessor', 'Instructor', 'Laurea', 'Mphil', 'Postdoctoral Researcher', 'Postdoctoral researcher', 'Project Advisor', 'Project advisor', 'Scholarship', 'Visitor', 'academic visits', 'computer science magnet', 'gastprofessor', 'instructor', 'laurea', 'mphil', 'postdoctoral researcher', 'project advisor', 'scholarship', 'visitor']}

# %%
for i in fellow:
    if i in pi:
        pi.remove(i)

# %%
pi
# Out:
# ['Academic Visits',
#  'Academic visits',
#  'Computer Science Magnet',
#  'Computer science magnet',
#  'External Examiner',
#  'Gastprofessor',
#  'Instructor',
#  'Laurea',
#  'Mphil',
#  'Postdoctoral Researcher',
#  'Postdoctoral researcher',
#  'Project Advisor',
#  'Project advisor',
#  'Scholarship',
#  'Visitor',
#  'academic visits',
#  'computer science magnet',
#  'gastprofessor',
#  'instructor',
#  'laurea',
#  'mphil',
#  'postdoctoral researcher',
#  'project advisor',
#  'scholarship',
#  'visitor']

# %%
for i in pi:
    if "doc" in i:
        print('"{}",'.format(i))
# Out:
# "Postdoctoral Researcher",
# "Postdoctoral researcher",
# "postdoctoral researcher",

# %%
#for i in pi:
#    if i.startswith("research") or i.startswith("Research"):
#        print('"{}",'.format(i))

# %%
fellow = ["External examiner",
"external examiner"]
print(fellow)
# Out:
# ['External examiner', 'external examiner']

# %%
print(['Academic Visits',
 'Academic visits',
 'Computer Science Magnet',
 'Computer science magnet',
 'External Examiner',
 'Gastprofessor',
 'Instructor',
 'Laurea',
 'Mphil',
 'Postdoctoral Researcher',
 'Postdoctoral researcher',
 'Project Advisor',
 'Project advisor',
 'Scholarship',
 'Visitor',
 'academic visits',
 'computer science magnet',
 'gastprofessor',
 'instructor',
 'laurea',
 'mphil',
 'postdoctoral researcher',
 'project advisor',
 'scholarship',
 'visitor'])
# Out:
# ['Academic Visits', 'Academic visits', 'Computer Science Magnet', 'Computer science magnet', 'External Examiner', 'Gastprofessor', 'Instructor', 'Laurea', 'Mphil', 'Postdoctoral Researcher', 'Postdoctoral researcher', 'Project Advisor', 'Project advisor', 'Scholarship', 'Visitor', 'academic visits', 'computer science magnet', 'gastprofessor', 'instructor', 'laurea', 'mphil', 'postdoctoral researcher', 'project advisor', 'scholarship', 'visitor']

# %%
pi = ['A.b.',
 'Academic Visits',
 'Academic visits',
 'Adjunct Professor',
 'Adjunct Research Professor',
 'Adjunct professor',
 'Adjunct research professor',
 'Advanced Grant',
 'Advanced grant',
 'Affiliated Professor',
 'Affiliated professor',
 'Assistant Editor',
 'Assistant Professor',
 'Assistant Professor In Economics',
 'Assistant editor',
 'Assistant professor',
 'Assistant professor in economics',
 'Associate Director',
 'Associate Editor',
 'Associate Faculty',
 'Associate Head',
 'Associate Professor',
 'Associate director',
 'Associate editor',
 'Associate faculty',
 'Associate head',
 'Associate professor',
 'Award',
 'B.a.',
 'B.sc',
 'Bachelor',
 'Board Member',
 'Board member',
 'Book Review Editor',
 'Book review editor',
 'Booth Professor',
 'Booth professor',
 'Chair',
 'Chairman',
 'Co-Director',
 'Co-director',
 'Co-editor',
 'Computer Science Magnet',
 'Computer science magnet',
 'Council Member',
 'Council Member Diplom',
 'Council member',
 'Council member diplom',
 'Directeur',
 'Director',
 'Editor-in-chief',
 'Editorial Board',
 'Editorial board',
 'Elected Member',
 'Elected member',
 'External Examiner',
 'External examiner',
 'Faculty Research Fellow',
 'Faculty research fellow',
 'Fellow',
 'Fellowship',
 'Former Associate Editor',
 'Former associate editor',
 'Full Professor',
 'Full professor',
 'Gastprofessor',
 'Grant',
 'Guest Editor',
 'Guest editor',
 'Instructor',
 'International Research Fellow',
 'International research fellow',
 'Invited Editor',
 'Invited editor',
 'Laurea',
 'Lecturer',
 'M.Sc',
 'M.a',
 'M.a.',
 'M.sc',
 'Member',
 'Mphil',
 'Msc',
 'Panel Member',
 'Panel member',
 'Ph. D.',
 'Ph. d.',
 'Ph.d',
 'Ph.d.',
 'Postdoctoral Researcher',
 'Postdoctoral researcher',
 'Prize',
 'Professor',
 'Professor Of Economics',
 'Professor of economics',
 'Project Advisor',
 'Project advisor',
 'Research Assistant',
 'Research Associate',
 'Research Chair',
 'Research Fellow',
 'Research Fellowship',
 'Research Professor',
 'Research Visitor',
 'Research assistant',
 'Research associate',
 'Research chair',
 'Research fellow',
 'Research fellowship',
 'Research professor',
 'Research visitor',
 'S.m.',
 'Scholarship',
 'Senior Lecturer',
 'Senior lecturer',
 'Teaching Assistant',
 'Teaching assistant',
 'University Professor',
 'University professor',
 'Visiting Assistant Professor',
 'Visiting Associate Professor',
 'Visiting Fellow',
 'Visiting Postdoctoral Researcher',
 'Visiting Professor',
 'Visiting Research Faculty',
 'Visiting Research Student',
 'Visiting Scholar',
 'Visiting Student',
 'Visiting assistant professor',
 'Visiting associate professor',
 'Visiting fellow',
 'Visiting postdoctoral researcher',
 'Visiting professor',
 'Visiting research faculty',
 'Visiting research student',
 'Visiting scholar',
 'Visiting student',
 'Visitor',
 'a.b.',
 'academic visits',
 'adjunct professor',
 'adjunct research professor',
 'advanced grant',
 'affiliated professor',
 'assistant editor',
 'assistant professor',
 'assistant professor in economics',
 'associate director',
 'associate editor',
 'associate faculty',
 'associate head',
 'associate professor',
 'award',
 'b.a.',
 'b.sc',
 'bachelor',
 'board member',
 'book review editor',
 'booth professor',
 'chair',
 'chairman',
 'co-director',
 'co-editor',
 'computer science magnet',
 'council member',
 'council member diplom',
 'directeur',
 'director',
 'editor-in-chief',
 'editorial board',
 'elected member',
 'external examiner',
 'faculty research fellow',
 'fellow',
 'fellowship',
 'former associate editor',
 'full professor',
 'gastprofessor',
 'grant',
 'guest editor',
 'instructor',
 'international research fellow',
 'invited editor',
 'laurea',
 'lecturer',
 'm.a',
 'm.a.',
 'm.sc',
 'member',
 'mphil',
 'msc',
 'msc',
 'panel member',
 'ph. d.',
 'ph.d',
 'ph.d.',
 'postdoctoral researcher',
 'prize',
 'professor',
 'professor of economics',
 'project advisor',
 'research assistant',
 'research associate',
 'research chair',
 'research fellow',
 'research fellowship',
 'research professor',
 'research visitor',
 's.m.',
 'scholarship',
 'senior lecturer',
 'teaching assistant',
 'university professor',
 'visiting assistant professor',
 'visiting fellow',
 'visiting postdoctoral researcher',
 'visiting professor',
 'visiting research faculty',
 'visiting research student',
 'visiting scholar',
 'visiting student',
 'visitor']
